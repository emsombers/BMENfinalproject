# %% [markdown]
# # Functional Connectivity Sliding Window Preprocessing & Calculation

# %% [markdown]
# We are going to make "chunks" of anxiety per subject that we can then align to fMRI data and calculate the functional connectivity. In order to standardize our feature sizes we will make window lengths of fMRI_TR, give a sliding stride, and then calculate mean anixety for the label for each chunk. We will prepare them in two different ways, one that can be used for regression (predicting continuous anxiety values) and one for classification (high vs low anxiety). Note these anxiety values are already z scored. The values from the reviewers are from 0 to 100 and then consensus annotations are calculated from the z scores. We are going to add a minmaxscaled value to each of the CSVs because that is better for some neural networks. Likely regression is best to use the continuous values and then minmax is good for binning for classification.

# %%
# code to add the minmaxscaler values 
import os
import pandas as pd
from sklearn.preprocessing import MinMaxScaler

anxiety_dir = "anxiety_aligned_csv"

for filename in os.listdir(anxiety_dir):
    if filename.endswith(".csv"):
        filepath = os.path.join(anxiety_dir, filename)

        df = pd.read_csv(filepath)

        anxiety_col = df.columns[2]

        scaler = MinMaxScaler()
        df["scaled_anxiety"] = scaler.fit_transform(df[[anxiety_col]])

        df.to_csv(filepath, index=False)
        print(f"Updated: {filename}")
# Out:
# Updated: sub-S25_Chatter_anxiety_aligned.csv
# Updated: sub-S28_LessonLearned_anxiety_aligned.csv
# Updated: sub-S20_Chatter_anxiety_aligned.csv
# Updated: sub-S09_Chatter_anxiety_aligned.csv
# Updated: sub-S25_LessonLearned_anxiety_aligned.csv
# Updated: sub-S11_LessonLearned_anxiety_aligned.csv
# Updated: sub-S02_LessonLearned_anxiety_aligned.csv
# Updated: sub-S10_Chatter_anxiety_aligned.csv
# Updated: sub-S13_LessonLearned_anxiety_aligned.csv
# Updated: sub-S27_LessonLearned_anxiety_aligned.csv
# Updated: sub-S06_Chatter_anxiety_aligned.csv
# Updated: sub-S15_Chatter_anxiety_aligned.csv
# Updated: sub-S03_Chatter_anxiety_aligned.csv
# Updated: sub-S21_Chatter_anxiety_aligned.csv
# Updated: sub-S08_Chatter_anxiety_aligned.csv
# Updated: sub-S29_LessonLearned_anxiety_aligned.csv
# Updated: sub-S24_LessonLearned_anxiety_aligned.csv
# Updated: sub-S24_Chatter_anxiety_aligned.csv
# Updated: sub-S01_LessonLearned_anxiety_aligned.csv
# Updated: sub-S32_Chatter_anxiety_aligned.csv
# Updated: sub-S10_LessonLearned_anxiety_aligned.csv
# Updated: sub-S14_Chatter_anxiety_aligned.csv
# Updated: sub-S03_LessonLearned_anxiety_aligned.csv
# Updated: sub-S02_Chatter_anxiety_aligned.csv
# Updated: sub-S26_LessonLearned_anxiety_aligned.csv
# Updated: sub-S11_Chatter_anxiety_aligned.csv
# Updated: sub-S07_Chatter_anxiety_aligned.csv
# Updated: sub-S08_LessonLearned_anxiety_aligned.csv
# Updated: sub-S19_LessonLearned_anxiety_aligned.csv
# Updated: sub-S04_Chatter_anxiety_aligned.csv
# Updated: sub-S17_Chatter_anxiety_aligned.csv
# Updated: sub-S05_LessonLearned_anxiety_aligned.csv
# Updated: sub-S14_LessonLearned_anxiety_aligned.csv
# Updated: sub-S01_Chatter_anxiety_aligned.csv
# Updated: sub-S20_LessonLearned_anxiety_aligned.csv
# Updated: sub-S28_Chatter_anxiety_aligned.csv
# Updated: sub-S31_LessonLearned_anxiety_aligned.csv
# Updated: sub-S22_LessonLearned_anxiety_aligned.csv
# Updated: sub-S27_Chatter_anxiety_aligned.csv
# Updated: sub-S16_LessonLearned_anxiety_aligned.csv
# Updated: sub-S07_LessonLearned_anxiety_aligned.csv
# Updated: sub-S22_Chatter_anxiety_aligned.csv
# Updated: sub-S16_Chatter_anxiety_aligned.csv
# Updated: sub-S29_Chatter_anxiety_aligned.csv
# Updated: sub-S09_LessonLearned_anxiety_aligned.csv
# Updated: sub-S15_LessonLearned_anxiety_aligned.csv
# Updated: sub-S04_LessonLearned_anxiety_aligned.csv
# Updated: sub-S13_Chatter_anxiety_aligned.csv
# Updated: sub-S30_LessonLearned_anxiety_aligned.csv
# Updated: sub-S21_LessonLearned_anxiety_aligned.csv
# Updated: sub-S05_Chatter_anxiety_aligned.csv
# Updated: sub-S23_Chatter_anxiety_aligned.csv
# Updated: sub-S23_LessonLearned_anxiety_aligned.csv
# Updated: sub-S32_LessonLearned_anxiety_aligned.csv
# Updated: sub-S06_LessonLearned_anxiety_aligned.csv
# Updated: sub-S17_LessonLearned_anxiety_aligned.csv
# Updated: sub-S26_Chatter_anxiety_aligned.csv
# Updated: sub-S19_Chatter_anxiety_aligned.csv
# Updated: sub-S30_Chatter_anxiety_aligned.csv

# %% [markdown]
# # Create the sliding windows

# %% [markdown]
# We are going to create CSVs for each subject that says when the window starts and what the mean z scored anxiety is as well as the binned anxiety level. We will do it based on mean and median.

# %%
from utils.sliding_windows import * 
import os

window_size = 60
step_size = 5 

anxiety_dir = "anxiety_aligned_csv"
output_dir = "LessonLearned_sliding_windows_csv"


for subj_num in range(1, 33):
    subj_id = f"sub-S{subj_num:02d}" 
    input_file = f"{subj_id}_LessonLearned_anxiety_aligned.csv"
    input_path = os.path.join(anxiety_dir, input_file)

    if not os.path.exists(input_path):
        print(f"Skipping {subj_id} — no file found.")
        continue

    output_path = os.path.join(output_dir, f"{subj_id}_anxiety_windows.csv")
    create_windows(
        anxiety_csv_path=input_path,
        output_csv_path=output_path,
        window_size=window_size,
        step_size=step_size
    )
# Out:
# DEBUG ROW: {'window_start_index': 72, 'window_start_TR': np.int64(72), 'mean_anxiety': np.float64(-0.16566439780381945), 'mean_scaled_anxiety': np.float64(0.2818266988075205), 'median_anxiety': np.float64(-0.37308565335937494), 'median_scaled_anxiety': np.float64(0.21893333805002047)}
# DEBUG ROW: {'window_start_index': 77, 'window_start_TR': np.int64(77), 'mean_anxiety': np.float64(-0.1414749144704861), 'mean_scaled_anxiety': np.float64(0.2891613275452844), 'median_anxiety': np.float64(-0.36956448669270836), 'median_scaled_anxiety': np.float64(0.2200010107186715)}
# DEBUG ROW: {'window_start_index': 82, 'window_start_TR': np.int64(82), 'mean_anxiety': np.float64(-0.22195144780381942), 'mean_scaled_anxiety': np.float64(0.264759587087732), 'median_anxiety': np.float64(-0.4329788200260416), 'median_scaled_anxiety': np.float64(0.2007727954962376)}
# DEBUG ROW: {'window_start_index': 87, 'window_start_TR': np.int64(87), 'mean_anxiety': np.float64(-0.3024508700260417), 'mean_scaled_anxiety': np.float64(0.24035090636196868), 'median_anxiety': np.float64(-0.4329788200260416), 'median_scaled_anxiety': np.float64(0.2007727954962376)}
# DEBUG ROW: {'window_start_index': 92, 'window_start_TR': np.int64(92), 'mean_anxiety': np.float64(-0.3813591422482639), 'mean_scaled_anxiety': np.float64(0.21642468714045784), 'median_anxiety': np.float64(-0.4329788200260416), 'median_scaled_anxiety': np.float64(0.2007727954962376)}
# DEBUG ROW: {'window_start_index': 97, 'window_start_TR': np.int64(97), 'mean_anxiety': np.float64(-0.4337264200260417), 'mean_scaled_anxiety': np.float64(0.200546111512591), 'median_anxiety': np.float64(-0.4329788200260416), 'median_scaled_anxiety': np.float64(0.2007727954962376)}
# DEBUG ROW: {'window_start_index': 102, 'window_start_TR': np.int64(102), 'mean_anxiety': np.float64(-0.47558415335937493), 'mean_scaled_anxiety': np.float64(0.18785419372444775), 'median_anxiety': np.float64(-0.4329788200260416), 'median_scaled_anxiety': np.float64(0.2007727954962376)}
# DEBUG ROW: {'window_start_index': 107, 'window_start_TR': np.int64(107), 'mean_anxiety': np.float64(-0.4916634589149306), 'mean_scaled_anxiety': np.float64(0.18297869741946676), 'median_anxiety': np.float64(-0.4329788200260416), 'median_scaled_anxiety': np.float64(0.2007727954962376)}
# DEBUG ROW: {'window_start_index': 112, 'window_start_TR': np.int64(112), 'mean_anxiety': np.float64(-0.46471730335937494), 'mean_scaled_anxiety': np.float64(0.19114919218310175), 'median_anxiety': np.float64(-0.4329788200260416), 'median_scaled_anxiety': np.float64(0.2007727954962376)}
# DEBUG ROW: {'window_start_index': 117, 'window_start_TR': np.int64(117), 'mean_anxiety': np.float64(-0.4253196200260417), 'mean_scaled_anxiety': np.float64(0.20309518443088956), 'median_anxiety': np.float64(-0.4314618200260416), 'median_scaled_anxiety': np.float64(0.2012327735636424)}
# DEBUG ROW: {'window_start_index': 122, 'window_start_TR': np.int64(122), 'mean_anxiety': np.float64(-0.3934139978038194), 'mean_scaled_anxiety': np.float64(0.21276946686274603), 'median_anxiety': np.float64(-0.41668498669270826), 'median_scaled_anxiety': np.float64(0.2057133399703859)}
# DEBUG ROW: {'window_start_index': 127, 'window_start_TR': np.int64(127), 'mean_anxiety': np.float64(-0.3746559366927083), 'mean_scaled_anxiety': np.float64(0.21845720364465146), 'median_anxiety': np.float64(-0.3915558200260416), 'median_scaled_anxiety': np.float64(0.2133328953552423)}
# DEBUG ROW: {'window_start_index': 132, 'window_start_TR': np.int64(132), 'mean_anxiety': np.float64(-0.33834792558159715), 'mean_scaled_anxiety': np.float64(0.2294663590712843), 'median_anxiety': np.float64(-0.34315698669270833), 'median_scaled_anxiety': np.float64(0.2280081767140525)}
# DEBUG ROW: {'window_start_index': 137, 'window_start_TR': np.int64(137), 'mean_anxiety': np.float64(-0.2962909533593749), 'mean_scaled_anxiety': np.float64(0.24221868919895492), 'median_anxiety': np.float64(-0.31539665335937495), 'median_scaled_anxiety': np.float64(0.23642554288226642)}
# DEBUG ROW: {'window_start_index': 142, 'window_start_TR': np.int64(142), 'mean_anxiety': np.float64(-0.2715957311371528), 'mean_scaled_anxiety': np.float64(0.24970666585809168), 'median_anxiety': np.float64(-0.29059348669270824), 'median_scaled_anxiety': np.float64(0.243946249981049)}
# DEBUG ROW: {'window_start_index': 147, 'window_start_TR': np.int64(147), 'mean_anxiety': np.float64(-0.2869092255815972), 'mean_scaled_anxiety': np.float64(0.24506337542976597), 'median_anxiety': np.float64(-0.31004132002604157), 'median_scaled_anxiety': np.float64(0.23804936349991657)}
# DEBUG ROW: {'window_start_index': 152, 'window_start_TR': np.int64(152), 'mean_anxiety': np.float64(-0.3215578700260416), 'mean_scaled_anxiety': np.float64(0.23455736586499829), 'median_anxiety': np.float64(-0.3418934866927083), 'median_scaled_anxiety': np.float64(0.2283912896264889)}
# DEBUG ROW: {'window_start_index': 157, 'window_start_TR': np.int64(157), 'mean_anxiety': np.float64(-0.3630400478038195), 'mean_scaled_anxiety': np.float64(0.22197932238051196), 'median_anxiety': np.float64(-0.40245665335937497), 'median_scaled_anxiety': np.float64(0.2100275926197322)}
# DEBUG ROW: {'window_start_index': 162, 'window_start_TR': np.int64(162), 'mean_anxiety': np.float64(-0.40718386447048616), 'mean_scaled_anxiety': np.float64(0.20859422845947942), 'median_anxiety': np.float64(-0.4124789866927082), 'median_scaled_anxiety': np.float64(0.206988664790099)}
# DEBUG ROW: {'window_start_index': 167, 'window_start_TR': np.int64(167), 'mean_anxiety': np.float64(-0.4411984700260417), 'mean_scaled_anxiety': np.float64(0.198280469377751), 'median_anxiety': np.float64(-0.41573515335937494), 'median_scaled_anxiety': np.float64(0.2060013442558331)}
# DEBUG ROW: {'window_start_index': 172, 'window_start_TR': np.int64(172), 'mean_anxiety': np.float64(-0.47234822002604154), 'mean_scaled_anxiety': np.float64(0.1888353791963776), 'median_anxiety': np.float64(-0.4830344866927083), 'median_scaled_anxiety': np.float64(0.18559513642175265)}
# DEBUG ROW: {'window_start_index': 177, 'window_start_TR': np.int64(177), 'mean_anxiety': np.float64(-0.4843442089149306), 'mean_scaled_anxiety': np.float64(0.1851980082104046), 'median_anxiety': np.float64(-0.5808034866927083), 'median_scaled_anxiety': np.float64(0.15595005028325384)}
# DEBUG ROW: {'window_start_index': 182, 'window_start_TR': np.int64(182), 'mean_anxiety': np.float64(-0.4948512366927084), 'mean_scaled_anxiety': np.float64(0.182012113463278), 'median_anxiety': np.float64(-0.5808034866927083), 'median_scaled_anxiety': np.float64(0.15595005028325384)}
# DEBUG ROW: {'window_start_index': 187, 'window_start_TR': np.int64(187), 'mean_anxiety': np.float64(-0.4971297311371528), 'mean_scaled_anxiety': np.float64(0.1813212383998976), 'median_anxiety': np.float64(-0.5808034866927083), 'median_scaled_anxiety': np.float64(0.15595005028325384)}
# DEBUG ROW: {'window_start_index': 192, 'window_start_TR': np.int64(192), 'mean_anxiety': np.float64(-0.5170810533593749), 'mean_scaled_anxiety': np.float64(0.1752716862324956), 'median_anxiety': np.float64(-0.5808034866927083), 'median_scaled_anxiety': np.float64(0.15595005028325384)}
# DEBUG ROW: {'window_start_index': 197, 'window_start_TR': np.int64(197), 'mean_anxiety': np.float64(-0.5296654978038194), 'mean_scaled_anxiety': np.float64(0.17145588634131628), 'median_anxiety': np.float64(-0.5808034866927083), 'median_scaled_anxiety': np.float64(0.15595005028325384)}
# DEBUG ROW: {'window_start_index': 202, 'window_start_TR': np.int64(202), 'mean_anxiety': np.float64(-0.5061775755815972), 'mean_scaled_anxiety': np.float64(0.1785777908048184), 'median_anxiety': np.float64(-0.5808034866927083), 'median_scaled_anxiety': np.float64(0.15595005028325384)}
# DEBUG ROW: {'window_start_index': 207, 'window_start_TR': np.int64(207), 'mean_anxiety': np.float64(-0.4529814311371527), 'mean_scaled_anxiety': np.float64(0.19470769173754326), 'median_anxiety': np.float64(-0.4087614866927083), 'median_scaled_anxiety': np.float64(0.20811586878850205)}
# DEBUG ROW: {'window_start_index': 212, 'window_start_TR': np.int64(212), 'mean_anxiety': np.float64(-0.3816722200260416), 'mean_scaled_anxiety': np.float64(0.21632975707376728), 'median_anxiety': np.float64(-0.2520558200260416), 'median_scaled_anxiety': np.float64(0.2556314717579935)}
# DEBUG ROW: {'window_start_index': 217, 'window_start_TR': np.int64(217), 'mean_anxiety': np.float64(-0.2836565866927083), 'mean_scaled_anxiety': np.float64(0.24604962628677118), 'median_anxiety': np.float64(-0.23953482002604165), 'median_scaled_anxiety': np.float64(0.2594280343037917)}
# DEBUG ROW: {'window_start_index': 222, 'window_start_TR': np.int64(222), 'mean_anxiety': np.float64(-0.12022525891493054), 'mean_scaled_anxiety': np.float64(0.29560455463524), 'median_anxiety': np.float64(-0.233285153359375), 'median_scaled_anxiety': np.float64(0.2613230307410084)}
# DEBUG ROW: {'window_start_index': 227, 'window_start_TR': np.int64(227), 'mean_anxiety': np.float64(0.08618471330729167), 'mean_scaled_anxiety': np.float64(0.3581912785085835), 'median_anxiety': np.float64(-0.04166748669270825), 'median_scaled_anxiety': np.float64(0.3194244967884414)}
# DEBUG ROW: {'window_start_index': 232, 'window_start_TR': np.int64(232), 'mean_anxiety': np.float64(0.30473274664062494), 'mean_scaled_anxiety': np.float64(0.4244584518822109), 'median_anxiety': np.float64(0.02443167997395835), 'median_scaled_anxiety': np.float64(0.3394667953648442)}
# DEBUG ROW: {'window_start_index': 237, 'window_start_TR': np.int64(237), 'mean_anxiety': np.float64(0.5145580799739583), 'mean_scaled_anxiety': np.float64(0.48808076652904053), 'median_anxiety': np.float64(0.1468876799739583), 'median_scaled_anxiety': np.float64(0.3765973650564234)}
# DEBUG ROW: {'window_start_index': 242, 'window_start_TR': np.int64(242), 'mean_anxiety': np.float64(0.7042286855295139), 'mean_scaled_anxiety': np.float64(0.5455918532706013), 'median_anxiety': np.float64(0.1923841799739583), 'median_scaled_anxiety': np.float64(0.39039261366794853)}
# DEBUG ROW: {'window_start_index': 247, 'window_start_TR': np.int64(247), 'mean_anxiety': np.float64(0.8830581688628472), 'mean_scaled_anxiety': np.float64(0.5998157426171211), 'median_anxiety': np.float64(0.7767740133072918), 'median_scaled_anxiety': np.float64(0.5675887284653753)}
# DEBUG ROW: {'window_start_index': 252, 'window_start_TR': np.int64(252), 'mean_anxiety': np.float64(1.0361248521961806), 'mean_scaled_anxiety': np.float64(0.6462279490665171), 'median_anxiety': np.float64(1.2295240133072918), 'median_scaled_anxiety': np.float64(0.7048695920234083)}
# DEBUG ROW: {'window_start_index': 257, 'window_start_TR': np.int64(257), 'mean_anxiety': np.float64(1.0627827577517361), 'mean_scaled_anxiety': np.float64(0.654311041933033), 'median_anxiety': np.float64(1.2295240133072918), 'median_scaled_anxiety': np.float64(0.7048695920234083)}
# DEBUG ROW: {'window_start_index': 262, 'window_start_TR': np.int64(262), 'mean_anxiety': np.float64(1.0350095188628472), 'mean_scaled_anxiety': np.float64(0.6458897625990294), 'median_anxiety': np.float64(1.2295240133072918), 'median_scaled_anxiety': np.float64(0.7048695920234083)}
# DEBUG ROW: {'window_start_index': 267, 'window_start_TR': np.int64(267), 'mean_anxiety': np.float64(1.0153461244184026), 'mean_scaled_anxiety': np.float64(0.6399275146259414), 'median_anxiety': np.float64(1.2295240133072918), 'median_scaled_anxiety': np.float64(0.7048695920234083)}
# DEBUG ROW: {'window_start_index': 272, 'window_start_TR': np.int64(272), 'mean_anxiety': np.float64(0.9913760355295138), 'mean_scaled_anxiety': np.float64(0.6326594097066052), 'median_anxiety': np.float64(1.2295240133072918), 'median_scaled_anxiety': np.float64(0.7048695920234083)}
# DEBUG ROW: {'window_start_index': 277, 'window_start_TR': np.int64(277), 'mean_anxiety': np.float64(0.9531350077517361), 'mean_scaled_anxiety': np.float64(0.6210641334687697), 'median_anxiety': np.float64(1.2295240133072918), 'median_scaled_anxiety': np.float64(0.7048695920234083)}
# DEBUG ROW: {'window_start_index': 282, 'window_start_TR': np.int64(282), 'mean_anxiety': np.float64(0.8425580966406251), 'mean_scaled_anxiety': np.float64(0.5875354888593535), 'median_anxiety': np.float64(1.0868213466406251), 'median_scaled_anxiety': np.float64(0.6615999171210689)}
# DEBUG ROW: {'window_start_index': 287, 'window_start_TR': np.int64(287), 'mean_anxiety': np.float64(0.7072025077517362), 'mean_scaled_anxiety': np.float64(0.546493562564328), 'median_anxiety': np.float64(0.042140179973958344), 'median_scaled_anxiety': np.float64(0.34483628884318196)}
# DEBUG ROW: {'window_start_index': 292, 'window_start_TR': np.int64(292), 'mean_anxiety': np.float64(0.5825247299739584), 'mean_scaled_anxiety': np.float64(0.5086893151875641), 'median_anxiety': np.float64(0.042140179973958344), 'median_scaled_anxiety': np.float64(0.34483628884318196)}
# DEBUG ROW: {'window_start_index': 297, 'window_start_TR': np.int64(297), 'mean_anxiety': np.float64(0.43574319664062505), 'mean_scaled_anxiety': np.float64(0.46418286427564315), 'median_anxiety': np.float64(0.00422567997395835), 'median_scaled_anxiety': np.float64(0.3333400209218765)}
# DEBUG ROW: {'window_start_index': 302, 'window_start_TR': np.int64(302), 'mean_anxiety': np.float64(0.2752751188628472), 'mean_scaled_anxiety': np.float64(0.4155264395581813), 'median_anxiety': np.float64(-0.0222509866927083), 'median_scaled_anxiety': np.float64(0.3253118825140616)}
# DEBUG ROW: {'window_start_index': 307, 'window_start_TR': np.int64(307), 'mean_anxiety': np.float64(0.122768046640625), 'mean_scaled_anxiety': np.float64(0.36928391592842086), 'median_anxiety': np.float64(-0.0222509866927083), 'median_scaled_anxiety': np.float64(0.3253118825140616)}
# DEBUG ROW: {'window_start_index': 312, 'window_start_TR': np.int64(312), 'mean_anxiety': np.float64(-0.014960114470486086), 'mean_scaled_anxiety': np.float64(0.32752258872004275), 'median_anxiety': np.float64(-0.0476003200260416), 'median_scaled_anxiety': np.float64(0.31762556916095186)}
# DEBUG ROW: {'window_start_index': 317, 'window_start_TR': np.int64(317), 'mean_anxiety': np.float64(-0.02827928669270831), 'mean_scaled_anxiety': np.float64(0.3234840079038201), 'median_anxiety': np.float64(-0.04131748669270825), 'median_scaled_anxiety': np.float64(0.3195306222489501)}
# DEBUG ROW: {'window_start_index': 322, 'window_start_TR': np.int64(322), 'mean_anxiety': np.float64(0.002641552196180574), 'mean_scaled_anxiety': np.float64(0.33285968866495863), 'median_anxiety': np.float64(-0.0222509866927083), 'median_scaled_anxiety': np.float64(0.3253118825140616)}
# DEBUG ROW: {'window_start_index': 327, 'window_start_TR': np.int64(327), 'mean_anxiety': np.float64(0.031242507751736124), 'mean_scaled_anxiety': np.float64(0.34153194460587866), 'median_anxiety': np.float64(0.0241321799739583), 'median_scaled_anxiety': np.float64(0.3393759822922089)}
# DEBUG ROW: {'window_start_index': 332, 'window_start_TR': np.int64(332), 'mean_anxiety': np.float64(0.04865336886284723), 'mean_scaled_anxiety': np.float64(0.3468111893295061), 'median_anxiety': np.float64(0.052343846640624955), 'median_scaled_anxiety': np.float64(0.34793019976854545)}
# DEBUG ROW: {'window_start_index': 337, 'window_start_TR': np.int64(337), 'mean_anxiety': np.float64(0.07270495219618055), 'mean_scaled_anxiety': np.float64(0.3541040046358297), 'median_anxiety': np.float64(0.06836384664062495), 'median_scaled_anxiety': np.float64(0.35278771370382905)}
# DEBUG ROW: {'window_start_index': 342, 'window_start_TR': np.int64(342), 'mean_anxiety': np.float64(0.13573503552951388), 'mean_scaled_anxiety': np.float64(0.373215709263405), 'median_anxiety': np.float64(0.0913976799739583), 'median_scaled_anxiety': np.float64(0.35977193133177343)}
# DEBUG ROW: {'window_start_index': 347, 'window_start_TR': np.int64(347), 'mean_anxiety': np.float64(0.16887440219618058), 'mean_scaled_anxiety': np.float64(0.3832640822590236), 'median_anxiety': np.float64(0.11664084664062495), 'median_scaled_anxiety': np.float64(0.3674260532951955)}
# DEBUG ROW: {'window_start_index': 352, 'window_start_TR': np.int64(352), 'mean_anxiety': np.float64(0.10546143552951387), 'mean_scaled_anxiety': np.float64(0.364036281431245), 'median_anxiety': np.float64(0.07963917997395831), 'median_scaled_anxiety': np.float64(0.3562065706820835)}
# DEBUG ROW: {'window_start_index': 357, 'window_start_TR': np.int64(357), 'mean_anxiety': np.float64(0.03724168552951389), 'mean_scaled_anxiety': np.float64(0.34335098890399357), 'median_anxiety': np.float64(0.06405984664062495), 'median_scaled_anxiety': np.float64(0.35148267375517356)}
# DEBUG ROW: {'window_start_index': 362, 'window_start_TR': np.int64(362), 'mean_anxiety': np.float64(-0.02985543113715278), 'mean_scaled_anxiety': np.float64(0.3230060963181203), 'median_anxiety': np.float64(0.05772834664062495), 'median_scaled_anxiety': np.float64(0.34956286417457133)}
# DEBUG ROW: {'window_start_index': 367, 'window_start_TR': np.int64(367), 'mean_anxiety': np.float64(-0.10599574224826387), 'mean_scaled_anxiety': np.float64(0.2999191660897147), 'median_anxiety': np.float64(0.0024288466406250505), 'median_scaled_anxiety': np.float64(0.33279519302199834)}
# DEBUG ROW: {'window_start_index': 372, 'window_start_TR': np.int64(372), 'mean_anxiety': np.float64(-0.17372759224826387), 'mean_scaled_anxiety': np.float64(0.2793818124544123), 'median_anxiety': np.float64(0.0024288466406250505), 'median_scaled_anxiety': np.float64(0.33279519302199834)}
# DEBUG ROW: {'window_start_index': 377, 'window_start_TR': np.int64(377), 'mean_anxiety': np.float64(-0.2329231422482639), 'mean_scaled_anxiety': np.float64(0.2614327981577967), 'median_anxiety': np.float64(-0.19025015335937495), 'median_scaled_anxiety': np.float64(0.2743719141495561)}
# DEBUG ROW: {'window_start_index': 382, 'window_start_TR': np.int64(382), 'mean_anxiety': np.float64(-0.28239870335937495), 'mean_scaled_anxiety': np.float64(0.24643103613824602), 'median_anxiety': np.float64(-0.4921181533593749), 'median_scaled_anxiety': np.float64(0.182840826970017)}
# DEBUG ROW: {'window_start_index': 387, 'window_start_TR': np.int64(387), 'mean_anxiety': np.float64(-0.3832870700260417), 'mean_scaled_anxiety': np.float64(0.2158401093597602), 'median_anxiety': np.float64(-0.595847153359375), 'median_scaled_anxiety': np.float64(0.15138857584685583)}
# DEBUG ROW: {'window_start_index': 392, 'window_start_TR': np.int64(392), 'mean_anxiety': np.float64(-0.48099716447048607), 'mean_scaled_anxiety': np.float64(0.18621288430471816), 'median_anxiety': np.float64(-0.6651474866927083), 'median_scaled_anxiety': np.float64(0.13037563359426713)}
# DEBUG ROW: {'window_start_index': 397, 'window_start_TR': np.int64(397), 'mean_anxiety': np.float64(-0.5774254589149305), 'mean_scaled_anxiety': np.float64(0.1569743210076191), 'median_anxiety': np.float64(-0.7530619866927084), 'median_scaled_anxiety': np.float64(0.103718585600291)}
# DEBUG ROW: {'window_start_index': 402, 'window_start_TR': np.int64(402), 'mean_anxiety': np.float64(-0.7046592866927083), 'mean_scaled_anxiety': np.float64(0.11839503939276019), 'median_anxiety': np.float64(-0.7819754866927082), 'median_scaled_anxiety': np.float64(0.09495156130766774)}
# DEBUG ROW: {'window_start_index': 407, 'window_start_TR': np.int64(407), 'mean_anxiety': np.float64(-0.8239400033593752), 'mean_scaled_anxiety': np.float64(0.08222726514688265), 'median_anxiety': np.float64(-0.827384153359375), 'median_scaled_anxiety': np.float64(0.08118294513313686)}
# DEBUG ROW: {'window_start_index': 412, 'window_start_TR': np.int64(412), 'mean_anxiety': np.float64(-0.863615325581597), 'mean_scaled_anxiety': np.float64(0.07019708845641354), 'median_anxiety': np.float64(-0.8811744866927084), 'median_scaled_anxiety': np.float64(0.0648728768590906)}
# DEBUG ROW: {'window_start_index': 417, 'window_start_TR': np.int64(417), 'mean_anxiety': np.float64(-0.8772195089149305), 'mean_scaled_anxiety': np.float64(0.06607208782471437), 'median_anxiety': np.float64(-0.8811744866927084), 'median_scaled_anxiety': np.float64(0.0648728768590906)}
# DEBUG ROW: {'window_start_index': 422, 'window_start_TR': np.int64(422), 'mean_anxiety': np.float64(-0.8684432255815971), 'mean_scaled_anxiety': np.float64(0.0687331938541566), 'median_anxiety': np.float64(-0.8811744866927084), 'median_scaled_anxiety': np.float64(0.0648728768590906)}
# DEBUG ROW: {'window_start_index': 427, 'window_start_TR': np.int64(427), 'mean_anxiety': np.float64(-0.835966603359375), 'mean_scaled_anxiety': np.float64(0.078580612394443), 'median_anxiety': np.float64(-0.8804969866927084), 'median_scaled_anxiety': np.float64(0.0650783054290753)}
# DEBUG ROW: {'window_start_index': 432, 'window_start_TR': np.int64(432), 'mean_anxiety': np.float64(-0.7492420700260418), 'mean_scaled_anxiety': np.float64(0.1048768439298763), 'median_anxiety': np.float64(-0.8533791533593751), 'median_scaled_anxiety': np.float64(0.07330085557335536)}
# DEBUG ROW: {'window_start_index': 437, 'window_start_TR': np.int64(437), 'mean_anxiety': np.float64(-0.6602351755815973), 'mean_scaled_anxiety': np.float64(0.13186512296234898), 'median_anxiety': np.float64(-0.8533791533593751), 'median_scaled_anxiety': np.float64(0.07330085557335536)}
# DEBUG ROW: {'window_start_index': 442, 'window_start_TR': np.int64(442), 'mean_anxiety': np.float64(-0.515510342248264), 'mean_scaled_anxiety': np.float64(0.17574795034676072), 'median_anxiety': np.float64(-0.8533791533593751), 'median_scaled_anxiety': np.float64(0.07330085557335536)}
# DEBUG ROW: {'window_start_index': 447, 'window_start_TR': np.int64(447), 'mean_anxiety': np.float64(-0.2621459311371528), 'mean_scaled_anxiety': np.float64(0.25257199264870617), 'median_anxiety': np.float64(-0.7150424866927083), 'median_scaled_anxiety': np.float64(0.1152466911597491)}
# DEBUG ROW: {'window_start_index': 452, 'window_start_TR': np.int64(452), 'mean_anxiety': np.float64(0.005412646640625004), 'mean_scaled_anxiety': np.float64(0.33369992773361495), 'median_anxiety': np.float64(-0.6209236533593749), 'median_scaled_anxiety': np.float64(0.14378498981700935)}
# DEBUG ROW: {'window_start_index': 457, 'window_start_TR': np.int64(457), 'mean_anxiety': np.float64(0.26450884664062496), 'mean_scaled_anxiety': np.float64(0.41226193785090887), 'median_anxiety': np.float64(-0.15357815335937494), 'median_scaled_anxiety': np.float64(0.2854914366860556)}
# DEBUG ROW: {'window_start_index': 462, 'window_start_TR': np.int64(462), 'mean_anxiety': np.float64(0.5211907133072916), 'mean_scaled_anxiety': np.float64(0.49009188443442714), 'median_anxiety': np.float64(0.3041876799739583), 'median_scaled_anxiety': np.float64(0.4242931791650453)}
# DEBUG ROW: {'window_start_index': 467, 'window_start_TR': np.int64(467), 'mean_anxiety': np.float64(0.7720712410850694), 'mean_scaled_anxiety': np.float64(0.5661627745575157), 'median_anxiety': np.float64(0.49278434664062504), 'median_scaled_anxiety': np.float64(0.4814786308804876)}
# DEBUG ROW: {'window_start_index': 472, 'window_start_TR': np.int64(472), 'mean_anxiety': np.float64(1.012785235529514), 'mean_scaled_anxiety': np.float64(0.6391510131612416), 'median_anxiety': np.float64(1.8745671799739587), 'median_scaled_anxiety': np.float64(0.900456743767656)}
# DEBUG ROW: {'window_start_index': 477, 'window_start_TR': np.int64(477), 'mean_anxiety': np.float64(1.2457396521961805), 'mean_scaled_anxiety': np.float64(0.7097864267220542), 'median_anxiety': np.float64(1.9612966799739582), 'median_scaled_anxiety': np.float64(0.9267544812739098)}
# DEBUG ROW: {'window_start_index': 482, 'window_start_TR': np.int64(482), 'mean_anxiety': np.float64(1.469718424418403), 'mean_scaled_anxiety': np.float64(0.7777002848542125), 'median_anxiety': np.float64(1.9650156799739582), 'median_scaled_anxiety': np.float64(0.9278821400957151)}
# DEBUG ROW: {'window_start_index': 487, 'window_start_TR': np.int64(487), 'mean_anxiety': np.float64(1.6243573188628475), 'mean_scaled_anxiety': np.float64(0.8245892102412756), 'median_anxiety': np.float64(1.9650156799739582), 'median_scaled_anxiety': np.float64(0.9278821400957151)}
# DEBUG ROW: {'window_start_index': 492, 'window_start_TR': np.int64(492), 'mean_anxiety': np.float64(1.647459496640625), 'mean_scaled_anxiety': np.float64(0.831594150971048), 'median_anxiety': np.float64(1.9650156799739582), 'median_scaled_anxiety': np.float64(0.9278821400957151)}
# DEBUG ROW: {'window_start_index': 497, 'window_start_TR': np.int64(497), 'mean_anxiety': np.float64(1.6274617133072917), 'mean_scaled_anxiety': np.float64(0.8255305110698963), 'median_anxiety': np.float64(1.9650156799739582), 'median_scaled_anxiety': np.float64(0.9278821400957151)}
# DEBUG ROW: {'window_start_index': 502, 'window_start_TR': np.int64(502), 'mean_anxiety': np.float64(1.5396153244184025), 'mean_scaled_anxiety': np.float64(0.7988941154274415), 'median_anxiety': np.float64(1.9650156799739582), 'median_scaled_anxiety': np.float64(0.9278821400957151)}
# DEBUG ROW: {'window_start_index': 507, 'window_start_TR': np.int64(507), 'mean_anxiety': np.float64(1.3743774077517361), 'mean_scaled_anxiety': np.float64(0.7487914011424491), 'median_anxiety': np.float64(1.9614253466406248), 'median_scaled_anxiety': np.float64(0.9267934950146302)}
# DEBUG ROW: {'window_start_index': 512, 'window_start_TR': np.int64(512), 'mean_anxiety': np.float64(1.1992995910850694), 'mean_scaled_anxiety': np.float64(0.6957050756607153), 'median_anxiety': np.float64(1.8851446799739584), 'median_scaled_anxiety': np.float64(0.9036640067920295)}
# DEBUG ROW: {'window_start_index': 517, 'window_start_TR': np.int64(517), 'mean_anxiety': np.float64(1.0298188521961804), 'mean_scaled_anxiety': np.float64(0.6443158714837519), 'median_anxiety': np.float64(0.7883318466406251), 'median_scaled_anxiety': np.float64(0.5710932438510403)}
# DEBUG ROW: {'window_start_index': 522, 'window_start_TR': np.int64(522), 'mean_anxiety': np.float64(0.9362001910850695), 'mean_scaled_anxiety': np.float64(0.615929232847683), 'median_anxiety': np.float64(0.7338475133072917), 'median_scaled_anxiety': np.float64(0.5545727439495853)}
# ✅ Saved: LessonLearned_sliding_windows_csv/sub-S01_anxiety_windows.csv with 91 windows
# 📊 Columns: ['window_start_index', 'window_start_TR', 'mean_anxiety', 'mean_scaled_anxiety', 'median_anxiety', 'median_scaled_anxiety', 'binned_by_mean', 'binned_by_median']
# 📊 Bin counts (mean):
# binned_by_mean
# medium    53
# high      25
# low       13
# Name: count, dtype: int64
# 📊 Bin counts (median):
# binned_by_median
# medium    52
# low       20
# high      19
# Name: count, dtype: int64
# DEBUG ROW: {'window_start_index': 72, 'window_start_TR': np.int64(72), 'mean_anxiety': np.float64(-0.16566439780381945), 'mean_scaled_anxiety': np.float64(0.2818266988075205), 'median_anxiety': np.float64(-0.37308565335937494), 'median_scaled_anxiety': np.float64(0.21893333805002047)}
# DEBUG ROW: {'window_start_index': 77, 'window_start_TR': np.int64(77), 'mean_anxiety': np.float64(-0.1414749144704861), 'mean_scaled_anxiety': np.float64(0.2891613275452844), 'median_anxiety': np.float64(-0.36956448669270836), 'median_scaled_anxiety': np.float64(0.2200010107186715)}
# DEBUG ROW: {'window_start_index': 82, 'window_start_TR': np.int64(82), 'mean_anxiety': np.float64(-0.22195144780381942), 'mean_scaled_anxiety': np.float64(0.264759587087732), 'median_anxiety': np.float64(-0.4329788200260416), 'median_scaled_anxiety': np.float64(0.2007727954962376)}
# DEBUG ROW: {'window_start_index': 87, 'window_start_TR': np.int64(87), 'mean_anxiety': np.float64(-0.3024508700260417), 'mean_scaled_anxiety': np.float64(0.24035090636196868), 'median_anxiety': np.float64(-0.4329788200260416), 'median_scaled_anxiety': np.float64(0.2007727954962376)}
# DEBUG ROW: {'window_start_index': 92, 'window_start_TR': np.int64(92), 'mean_anxiety': np.float64(-0.3813591422482639), 'mean_scaled_anxiety': np.float64(0.21642468714045784), 'median_anxiety': np.float64(-0.4329788200260416), 'median_scaled_anxiety': np.float64(0.2007727954962376)}
# DEBUG ROW: {'window_start_index': 97, 'window_start_TR': np.int64(97), 'mean_anxiety': np.float64(-0.4337264200260417), 'mean_scaled_anxiety': np.float64(0.200546111512591), 'median_anxiety': np.float64(-0.4329788200260416), 'median_scaled_anxiety': np.float64(0.2007727954962376)}
# DEBUG ROW: {'window_start_index': 102, 'window_start_TR': np.int64(102), 'mean_anxiety': np.float64(-0.47558415335937493), 'mean_scaled_anxiety': np.float64(0.18785419372444775), 'median_anxiety': np.float64(-0.4329788200260416), 'median_scaled_anxiety': np.float64(0.2007727954962376)}
# DEBUG ROW: {'window_start_index': 107, 'window_start_TR': np.int64(107), 'mean_anxiety': np.float64(-0.4916634589149306), 'mean_scaled_anxiety': np.float64(0.18297869741946676), 'median_anxiety': np.float64(-0.4329788200260416), 'median_scaled_anxiety': np.float64(0.2007727954962376)}
# DEBUG ROW: {'window_start_index': 112, 'window_start_TR': np.int64(112), 'mean_anxiety': np.float64(-0.46471730335937494), 'mean_scaled_anxiety': np.float64(0.19114919218310175), 'median_anxiety': np.float64(-0.4329788200260416), 'median_scaled_anxiety': np.float64(0.2007727954962376)}
# DEBUG ROW: {'window_start_index': 117, 'window_start_TR': np.int64(117), 'mean_anxiety': np.float64(-0.4253196200260417), 'mean_scaled_anxiety': np.float64(0.20309518443088956), 'median_anxiety': np.float64(-0.4314618200260416), 'median_scaled_anxiety': np.float64(0.2012327735636424)}
# DEBUG ROW: {'window_start_index': 122, 'window_start_TR': np.int64(122), 'mean_anxiety': np.float64(-0.3934139978038194), 'mean_scaled_anxiety': np.float64(0.21276946686274603), 'median_anxiety': np.float64(-0.41668498669270826), 'median_scaled_anxiety': np.float64(0.2057133399703859)}
# DEBUG ROW: {'window_start_index': 127, 'window_start_TR': np.int64(127), 'mean_anxiety': np.float64(-0.3746559366927083), 'mean_scaled_anxiety': np.float64(0.21845720364465146), 'median_anxiety': np.float64(-0.3915558200260416), 'median_scaled_anxiety': np.float64(0.2133328953552423)}
# DEBUG ROW: {'window_start_index': 132, 'window_start_TR': np.int64(132), 'mean_anxiety': np.float64(-0.33834792558159715), 'mean_scaled_anxiety': np.float64(0.2294663590712843), 'median_anxiety': np.float64(-0.34315698669270833), 'median_scaled_anxiety': np.float64(0.2280081767140525)}
# DEBUG ROW: {'window_start_index': 137, 'window_start_TR': np.int64(137), 'mean_anxiety': np.float64(-0.2962909533593749), 'mean_scaled_anxiety': np.float64(0.24221868919895492), 'median_anxiety': np.float64(-0.31539665335937495), 'median_scaled_anxiety': np.float64(0.23642554288226642)}
# DEBUG ROW: {'window_start_index': 142, 'window_start_TR': np.int64(142), 'mean_anxiety': np.float64(-0.2715957311371528), 'mean_scaled_anxiety': np.float64(0.24970666585809168), 'median_anxiety': np.float64(-0.29059348669270824), 'median_scaled_anxiety': np.float64(0.243946249981049)}
# DEBUG ROW: {'window_start_index': 147, 'window_start_TR': np.int64(147), 'mean_anxiety': np.float64(-0.2869092255815972), 'mean_scaled_anxiety': np.float64(0.24506337542976597), 'median_anxiety': np.float64(-0.31004132002604157), 'median_scaled_anxiety': np.float64(0.23804936349991657)}
# DEBUG ROW: {'window_start_index': 152, 'window_start_TR': np.int64(152), 'mean_anxiety': np.float64(-0.3215578700260416), 'mean_scaled_anxiety': np.float64(0.23455736586499829), 'median_anxiety': np.float64(-0.3418934866927083), 'median_scaled_anxiety': np.float64(0.2283912896264889)}
# DEBUG ROW: {'window_start_index': 157, 'window_start_TR': np.int64(157), 'mean_anxiety': np.float64(-0.3630400478038195), 'mean_scaled_anxiety': np.float64(0.22197932238051196), 'median_anxiety': np.float64(-0.40245665335937497), 'median_scaled_anxiety': np.float64(0.2100275926197322)}
# DEBUG ROW: {'window_start_index': 162, 'window_start_TR': np.int64(162), 'mean_anxiety': np.float64(-0.40718386447048616), 'mean_scaled_anxiety': np.float64(0.20859422845947942), 'median_anxiety': np.float64(-0.4124789866927082), 'median_scaled_anxiety': np.float64(0.206988664790099)}
# DEBUG ROW: {'window_start_index': 167, 'window_start_TR': np.int64(167), 'mean_anxiety': np.float64(-0.4411984700260417), 'mean_scaled_anxiety': np.float64(0.198280469377751), 'median_anxiety': np.float64(-0.41573515335937494), 'median_scaled_anxiety': np.float64(0.2060013442558331)}
# DEBUG ROW: {'window_start_index': 172, 'window_start_TR': np.int64(172), 'mean_anxiety': np.float64(-0.47234822002604154), 'mean_scaled_anxiety': np.float64(0.1888353791963776), 'median_anxiety': np.float64(-0.4830344866927083), 'median_scaled_anxiety': np.float64(0.18559513642175265)}
# DEBUG ROW: {'window_start_index': 177, 'window_start_TR': np.int64(177), 'mean_anxiety': np.float64(-0.4843442089149306), 'mean_scaled_anxiety': np.float64(0.1851980082104046), 'median_anxiety': np.float64(-0.5808034866927083), 'median_scaled_anxiety': np.float64(0.15595005028325384)}
# DEBUG ROW: {'window_start_index': 182, 'window_start_TR': np.int64(182), 'mean_anxiety': np.float64(-0.4948512366927084), 'mean_scaled_anxiety': np.float64(0.182012113463278), 'median_anxiety': np.float64(-0.5808034866927083), 'median_scaled_anxiety': np.float64(0.15595005028325384)}
# DEBUG ROW: {'window_start_index': 187, 'window_start_TR': np.int64(187), 'mean_anxiety': np.float64(-0.4971297311371528), 'mean_scaled_anxiety': np.float64(0.1813212383998976), 'median_anxiety': np.float64(-0.5808034866927083), 'median_scaled_anxiety': np.float64(0.15595005028325384)}
# DEBUG ROW: {'window_start_index': 192, 'window_start_TR': np.int64(192), 'mean_anxiety': np.float64(-0.5170810533593749), 'mean_scaled_anxiety': np.float64(0.1752716862324956), 'median_anxiety': np.float64(-0.5808034866927083), 'median_scaled_anxiety': np.float64(0.15595005028325384)}
# DEBUG ROW: {'window_start_index': 197, 'window_start_TR': np.int64(197), 'mean_anxiety': np.float64(-0.5296654978038194), 'mean_scaled_anxiety': np.float64(0.17145588634131628), 'median_anxiety': np.float64(-0.5808034866927083), 'median_scaled_anxiety': np.float64(0.15595005028325384)}
# DEBUG ROW: {'window_start_index': 202, 'window_start_TR': np.int64(202), 'mean_anxiety': np.float64(-0.5061775755815972), 'mean_scaled_anxiety': np.float64(0.1785777908048184), 'median_anxiety': np.float64(-0.5808034866927083), 'median_scaled_anxiety': np.float64(0.15595005028325384)}
# DEBUG ROW: {'window_start_index': 207, 'window_start_TR': np.int64(207), 'mean_anxiety': np.float64(-0.4529814311371527), 'mean_scaled_anxiety': np.float64(0.19470769173754326), 'median_anxiety': np.float64(-0.4087614866927083), 'median_scaled_anxiety': np.float64(0.20811586878850205)}
# DEBUG ROW: {'window_start_index': 212, 'window_start_TR': np.int64(212), 'mean_anxiety': np.float64(-0.3816722200260416), 'mean_scaled_anxiety': np.float64(0.21632975707376728), 'median_anxiety': np.float64(-0.2520558200260416), 'median_scaled_anxiety': np.float64(0.2556314717579935)}
# DEBUG ROW: {'window_start_index': 217, 'window_start_TR': np.int64(217), 'mean_anxiety': np.float64(-0.2836565866927083), 'mean_scaled_anxiety': np.float64(0.24604962628677118), 'median_anxiety': np.float64(-0.23953482002604165), 'median_scaled_anxiety': np.float64(0.2594280343037917)}
# DEBUG ROW: {'window_start_index': 222, 'window_start_TR': np.int64(222), 'mean_anxiety': np.float64(-0.12022525891493054), 'mean_scaled_anxiety': np.float64(0.29560455463524), 'median_anxiety': np.float64(-0.233285153359375), 'median_scaled_anxiety': np.float64(0.2613230307410084)}
# DEBUG ROW: {'window_start_index': 227, 'window_start_TR': np.int64(227), 'mean_anxiety': np.float64(0.08618471330729167), 'mean_scaled_anxiety': np.float64(0.3581912785085835), 'median_anxiety': np.float64(-0.04166748669270825), 'median_scaled_anxiety': np.float64(0.3194244967884414)}
# DEBUG ROW: {'window_start_index': 232, 'window_start_TR': np.int64(232), 'mean_anxiety': np.float64(0.30473274664062494), 'mean_scaled_anxiety': np.float64(0.4244584518822109), 'median_anxiety': np.float64(0.02443167997395835), 'median_scaled_anxiety': np.float64(0.3394667953648442)}
# DEBUG ROW: {'window_start_index': 237, 'window_start_TR': np.int64(237), 'mean_anxiety': np.float64(0.5145580799739583), 'mean_scaled_anxiety': np.float64(0.48808076652904053), 'median_anxiety': np.float64(0.1468876799739583), 'median_scaled_anxiety': np.float64(0.3765973650564234)}
# DEBUG ROW: {'window_start_index': 242, 'window_start_TR': np.int64(242), 'mean_anxiety': np.float64(0.7042286855295139), 'mean_scaled_anxiety': np.float64(0.5455918532706013), 'median_anxiety': np.float64(0.1923841799739583), 'median_scaled_anxiety': np.float64(0.39039261366794853)}
# DEBUG ROW: {'window_start_index': 247, 'window_start_TR': np.int64(247), 'mean_anxiety': np.float64(0.8830581688628472), 'mean_scaled_anxiety': np.float64(0.5998157426171211), 'median_anxiety': np.float64(0.7767740133072918), 'median_scaled_anxiety': np.float64(0.5675887284653753)}
# DEBUG ROW: {'window_start_index': 252, 'window_start_TR': np.int64(252), 'mean_anxiety': np.float64(1.0361248521961806), 'mean_scaled_anxiety': np.float64(0.6462279490665171), 'median_anxiety': np.float64(1.2295240133072918), 'median_scaled_anxiety': np.float64(0.7048695920234083)}
# DEBUG ROW: {'window_start_index': 257, 'window_start_TR': np.int64(257), 'mean_anxiety': np.float64(1.0627827577517361), 'mean_scaled_anxiety': np.float64(0.654311041933033), 'median_anxiety': np.float64(1.2295240133072918), 'median_scaled_anxiety': np.float64(0.7048695920234083)}
# DEBUG ROW: {'window_start_index': 262, 'window_start_TR': np.int64(262), 'mean_anxiety': np.float64(1.0350095188628472), 'mean_scaled_anxiety': np.float64(0.6458897625990294), 'median_anxiety': np.float64(1.2295240133072918), 'median_scaled_anxiety': np.float64(0.7048695920234083)}
# DEBUG ROW: {'window_start_index': 267, 'window_start_TR': np.int64(267), 'mean_anxiety': np.float64(1.0153461244184026), 'mean_scaled_anxiety': np.float64(0.6399275146259414), 'median_anxiety': np.float64(1.2295240133072918), 'median_scaled_anxiety': np.float64(0.7048695920234083)}
# DEBUG ROW: {'window_start_index': 272, 'window_start_TR': np.int64(272), 'mean_anxiety': np.float64(0.9913760355295138), 'mean_scaled_anxiety': np.float64(0.6326594097066052), 'median_anxiety': np.float64(1.2295240133072918), 'median_scaled_anxiety': np.float64(0.7048695920234083)}
# DEBUG ROW: {'window_start_index': 277, 'window_start_TR': np.int64(277), 'mean_anxiety': np.float64(0.9531350077517361), 'mean_scaled_anxiety': np.float64(0.6210641334687697), 'median_anxiety': np.float64(1.2295240133072918), 'median_scaled_anxiety': np.float64(0.7048695920234083)}
# DEBUG ROW: {'window_start_index': 282, 'window_start_TR': np.int64(282), 'mean_anxiety': np.float64(0.8425580966406251), 'mean_scaled_anxiety': np.float64(0.5875354888593535), 'median_anxiety': np.float64(1.0868213466406251), 'median_scaled_anxiety': np.float64(0.6615999171210689)}
# DEBUG ROW: {'window_start_index': 287, 'window_start_TR': np.int64(287), 'mean_anxiety': np.float64(0.7072025077517362), 'mean_scaled_anxiety': np.float64(0.546493562564328), 'median_anxiety': np.float64(0.042140179973958344), 'median_scaled_anxiety': np.float64(0.34483628884318196)}
# DEBUG ROW: {'window_start_index': 292, 'window_start_TR': np.int64(292), 'mean_anxiety': np.float64(0.5825247299739584), 'mean_scaled_anxiety': np.float64(0.5086893151875641), 'median_anxiety': np.float64(0.042140179973958344), 'median_scaled_anxiety': np.float64(0.34483628884318196)}
# DEBUG ROW: {'window_start_index': 297, 'window_start_TR': np.int64(297), 'mean_anxiety': np.float64(0.43574319664062505), 'mean_scaled_anxiety': np.float64(0.46418286427564315), 'median_anxiety': np.float64(0.00422567997395835), 'median_scaled_anxiety': np.float64(0.3333400209218765)}
# DEBUG ROW: {'window_start_index': 302, 'window_start_TR': np.int64(302), 'mean_anxiety': np.float64(0.2752751188628472), 'mean_scaled_anxiety': np.float64(0.4155264395581813), 'median_anxiety': np.float64(-0.0222509866927083), 'median_scaled_anxiety': np.float64(0.3253118825140616)}
# DEBUG ROW: {'window_start_index': 307, 'window_start_TR': np.int64(307), 'mean_anxiety': np.float64(0.122768046640625), 'mean_scaled_anxiety': np.float64(0.36928391592842086), 'median_anxiety': np.float64(-0.0222509866927083), 'median_scaled_anxiety': np.float64(0.3253118825140616)}
# DEBUG ROW: {'window_start_index': 312, 'window_start_TR': np.int64(312), 'mean_anxiety': np.float64(-0.014960114470486086), 'mean_scaled_anxiety': np.float64(0.32752258872004275), 'median_anxiety': np.float64(-0.0476003200260416), 'median_scaled_anxiety': np.float64(0.31762556916095186)}
# DEBUG ROW: {'window_start_index': 317, 'window_start_TR': np.int64(317), 'mean_anxiety': np.float64(-0.02827928669270831), 'mean_scaled_anxiety': np.float64(0.3234840079038201), 'median_anxiety': np.float64(-0.04131748669270825), 'median_scaled_anxiety': np.float64(0.3195306222489501)}
# DEBUG ROW: {'window_start_index': 322, 'window_start_TR': np.int64(322), 'mean_anxiety': np.float64(0.002641552196180574), 'mean_scaled_anxiety': np.float64(0.33285968866495863), 'median_anxiety': np.float64(-0.0222509866927083), 'median_scaled_anxiety': np.float64(0.3253118825140616)}
# DEBUG ROW: {'window_start_index': 327, 'window_start_TR': np.int64(327), 'mean_anxiety': np.float64(0.031242507751736124), 'mean_scaled_anxiety': np.float64(0.34153194460587866), 'median_anxiety': np.float64(0.0241321799739583), 'median_scaled_anxiety': np.float64(0.3393759822922089)}
# DEBUG ROW: {'window_start_index': 332, 'window_start_TR': np.int64(332), 'mean_anxiety': np.float64(0.04865336886284723), 'mean_scaled_anxiety': np.float64(0.3468111893295061), 'median_anxiety': np.float64(0.052343846640624955), 'median_scaled_anxiety': np.float64(0.34793019976854545)}
# DEBUG ROW: {'window_start_index': 337, 'window_start_TR': np.int64(337), 'mean_anxiety': np.float64(0.07270495219618055), 'mean_scaled_anxiety': np.float64(0.3541040046358297), 'median_anxiety': np.float64(0.06836384664062495), 'median_scaled_anxiety': np.float64(0.35278771370382905)}
# DEBUG ROW: {'window_start_index': 342, 'window_start_TR': np.int64(342), 'mean_anxiety': np.float64(0.13573503552951388), 'mean_scaled_anxiety': np.float64(0.373215709263405), 'median_anxiety': np.float64(0.0913976799739583), 'median_scaled_anxiety': np.float64(0.35977193133177343)}
# DEBUG ROW: {'window_start_index': 347, 'window_start_TR': np.int64(347), 'mean_anxiety': np.float64(0.16887440219618058), 'mean_scaled_anxiety': np.float64(0.3832640822590236), 'median_anxiety': np.float64(0.11664084664062495), 'median_scaled_anxiety': np.float64(0.3674260532951955)}
# DEBUG ROW: {'window_start_index': 352, 'window_start_TR': np.int64(352), 'mean_anxiety': np.float64(0.10546143552951387), 'mean_scaled_anxiety': np.float64(0.364036281431245), 'median_anxiety': np.float64(0.07963917997395831), 'median_scaled_anxiety': np.float64(0.3562065706820835)}
# DEBUG ROW: {'window_start_index': 357, 'window_start_TR': np.int64(357), 'mean_anxiety': np.float64(0.03724168552951389), 'mean_scaled_anxiety': np.float64(0.34335098890399357), 'median_anxiety': np.float64(0.06405984664062495), 'median_scaled_anxiety': np.float64(0.35148267375517356)}
# DEBUG ROW: {'window_start_index': 362, 'window_start_TR': np.int64(362), 'mean_anxiety': np.float64(-0.02985543113715278), 'mean_scaled_anxiety': np.float64(0.3230060963181203), 'median_anxiety': np.float64(0.05772834664062495), 'median_scaled_anxiety': np.float64(0.34956286417457133)}
# DEBUG ROW: {'window_start_index': 367, 'window_start_TR': np.int64(367), 'mean_anxiety': np.float64(-0.10599574224826387), 'mean_scaled_anxiety': np.float64(0.2999191660897147), 'median_anxiety': np.float64(0.0024288466406250505), 'median_scaled_anxiety': np.float64(0.33279519302199834)}
# DEBUG ROW: {'window_start_index': 372, 'window_start_TR': np.int64(372), 'mean_anxiety': np.float64(-0.17372759224826387), 'mean_scaled_anxiety': np.float64(0.2793818124544123), 'median_anxiety': np.float64(0.0024288466406250505), 'median_scaled_anxiety': np.float64(0.33279519302199834)}
# DEBUG ROW: {'window_start_index': 377, 'window_start_TR': np.int64(377), 'mean_anxiety': np.float64(-0.2329231422482639), 'mean_scaled_anxiety': np.float64(0.2614327981577967), 'median_anxiety': np.float64(-0.19025015335937495), 'median_scaled_anxiety': np.float64(0.2743719141495561)}
# DEBUG ROW: {'window_start_index': 382, 'window_start_TR': np.int64(382), 'mean_anxiety': np.float64(-0.28239870335937495), 'mean_scaled_anxiety': np.float64(0.24643103613824602), 'median_anxiety': np.float64(-0.4921181533593749), 'median_scaled_anxiety': np.float64(0.182840826970017)}
# DEBUG ROW: {'window_start_index': 387, 'window_start_TR': np.int64(387), 'mean_anxiety': np.float64(-0.3832870700260417), 'mean_scaled_anxiety': np.float64(0.2158401093597602), 'median_anxiety': np.float64(-0.595847153359375), 'median_scaled_anxiety': np.float64(0.15138857584685583)}
# DEBUG ROW: {'window_start_index': 392, 'window_start_TR': np.int64(392), 'mean_anxiety': np.float64(-0.48099716447048607), 'mean_scaled_anxiety': np.float64(0.18621288430471816), 'median_anxiety': np.float64(-0.6651474866927083), 'median_scaled_anxiety': np.float64(0.13037563359426713)}
# DEBUG ROW: {'window_start_index': 397, 'window_start_TR': np.int64(397), 'mean_anxiety': np.float64(-0.5774254589149305), 'mean_scaled_anxiety': np.float64(0.1569743210076191), 'median_anxiety': np.float64(-0.7530619866927084), 'median_scaled_anxiety': np.float64(0.103718585600291)}
# DEBUG ROW: {'window_start_index': 402, 'window_start_TR': np.int64(402), 'mean_anxiety': np.float64(-0.7046592866927083), 'mean_scaled_anxiety': np.float64(0.11839503939276019), 'median_anxiety': np.float64(-0.7819754866927082), 'median_scaled_anxiety': np.float64(0.09495156130766774)}
# DEBUG ROW: {'window_start_index': 407, 'window_start_TR': np.int64(407), 'mean_anxiety': np.float64(-0.8239400033593752), 'mean_scaled_anxiety': np.float64(0.08222726514688265), 'median_anxiety': np.float64(-0.827384153359375), 'median_scaled_anxiety': np.float64(0.08118294513313686)}
# DEBUG ROW: {'window_start_index': 412, 'window_start_TR': np.int64(412), 'mean_anxiety': np.float64(-0.863615325581597), 'mean_scaled_anxiety': np.float64(0.07019708845641354), 'median_anxiety': np.float64(-0.8811744866927084), 'median_scaled_anxiety': np.float64(0.0648728768590906)}
# DEBUG ROW: {'window_start_index': 417, 'window_start_TR': np.int64(417), 'mean_anxiety': np.float64(-0.8772195089149305), 'mean_scaled_anxiety': np.float64(0.06607208782471437), 'median_anxiety': np.float64(-0.8811744866927084), 'median_scaled_anxiety': np.float64(0.0648728768590906)}
# DEBUG ROW: {'window_start_index': 422, 'window_start_TR': np.int64(422), 'mean_anxiety': np.float64(-0.8684432255815971), 'mean_scaled_anxiety': np.float64(0.0687331938541566), 'median_anxiety': np.float64(-0.8811744866927084), 'median_scaled_anxiety': np.float64(0.0648728768590906)}
# DEBUG ROW: {'window_start_index': 427, 'window_start_TR': np.int64(427), 'mean_anxiety': np.float64(-0.835966603359375), 'mean_scaled_anxiety': np.float64(0.078580612394443), 'median_anxiety': np.float64(-0.8804969866927084), 'median_scaled_anxiety': np.float64(0.0650783054290753)}
# DEBUG ROW: {'window_start_index': 432, 'window_start_TR': np.int64(432), 'mean_anxiety': np.float64(-0.7492420700260418), 'mean_scaled_anxiety': np.float64(0.1048768439298763), 'median_anxiety': np.float64(-0.8533791533593751), 'median_scaled_anxiety': np.float64(0.07330085557335536)}
# DEBUG ROW: {'window_start_index': 437, 'window_start_TR': np.int64(437), 'mean_anxiety': np.float64(-0.6602351755815973), 'mean_scaled_anxiety': np.float64(0.13186512296234898), 'median_anxiety': np.float64(-0.8533791533593751), 'median_scaled_anxiety': np.float64(0.07330085557335536)}
# DEBUG ROW: {'window_start_index': 442, 'window_start_TR': np.int64(442), 'mean_anxiety': np.float64(-0.515510342248264), 'mean_scaled_anxiety': np.float64(0.17574795034676072), 'median_anxiety': np.float64(-0.8533791533593751), 'median_scaled_anxiety': np.float64(0.07330085557335536)}
# ...
# DEBUG ROW: {'window_start_index': 257, 'window_start_TR': np.int64(257), 'mean_anxiety': np.float64(1.0627827577517361), 'mean_scaled_anxiety': np.float64(0.654311041933033), 'median_anxiety': np.float64(1.2295240133072918), 'median_scaled_anxiety': np.float64(0.7048695920234083)}
# DEBUG ROW: {'window_start_index': 262, 'window_start_TR': np.int64(262), 'mean_anxiety': np.float64(1.0350095188628472), 'mean_scaled_anxiety': np.float64(0.6458897625990294), 'median_anxiety': np.float64(1.2295240133072918), 'median_scaled_anxiety': np.float64(0.7048695920234083)}
# DEBUG ROW: {'window_start_index': 267, 'window_start_TR': np.int64(267), 'mean_anxiety': np.float64(1.0153461244184026), 'mean_scaled_anxiety': np.float64(0.6399275146259414), 'median_anxiety': np.float64(1.2295240133072918), 'median_scaled_anxiety': np.float64(0.7048695920234083)}
# DEBUG ROW: {'window_start_index': 272, 'window_start_TR': np.int64(272), 'mean_anxiety': np.float64(0.9913760355295138), 'mean_scaled_anxiety': np.float64(0.6326594097066052), 'median_anxiety': np.float64(1.2295240133072918), 'median_scaled_anxiety': np.float64(0.7048695920234083)}
# DEBUG ROW: {'window_start_index': 277, 'window_start_TR': np.int64(277), 'mean_anxiety': np.float64(0.9531350077517361), 'mean_scaled_anxiety': np.float64(0.6210641334687697), 'median_anxiety': np.float64(1.2295240133072918), 'median_scaled_anxiety': np.float64(0.7048695920234083)}
# DEBUG ROW: {'window_start_index': 282, 'window_start_TR': np.int64(282), 'mean_anxiety': np.float64(0.8425580966406251), 'mean_scaled_anxiety': np.float64(0.5875354888593535), 'median_anxiety': np.float64(1.0868213466406251), 'median_scaled_anxiety': np.float64(0.6615999171210689)}
# DEBUG ROW: {'window_start_index': 287, 'window_start_TR': np.int64(287), 'mean_anxiety': np.float64(0.7072025077517362), 'mean_scaled_anxiety': np.float64(0.546493562564328), 'median_anxiety': np.float64(0.042140179973958344), 'median_scaled_anxiety': np.float64(0.34483628884318196)}
# DEBUG ROW: {'window_start_index': 292, 'window_start_TR': np.int64(292), 'mean_anxiety': np.float64(0.5825247299739584), 'mean_scaled_anxiety': np.float64(0.5086893151875641), 'median_anxiety': np.float64(0.042140179973958344), 'median_scaled_anxiety': np.float64(0.34483628884318196)}
# DEBUG ROW: {'window_start_index': 297, 'window_start_TR': np.int64(297), 'mean_anxiety': np.float64(0.43574319664062505), 'mean_scaled_anxiety': np.float64(0.46418286427564315), 'median_anxiety': np.float64(0.00422567997395835), 'median_scaled_anxiety': np.float64(0.3333400209218765)}
# DEBUG ROW: {'window_start_index': 302, 'window_start_TR': np.int64(302), 'mean_anxiety': np.float64(0.2752751188628472), 'mean_scaled_anxiety': np.float64(0.4155264395581813), 'median_anxiety': np.float64(-0.0222509866927083), 'median_scaled_anxiety': np.float64(0.3253118825140616)}
# DEBUG ROW: {'window_start_index': 307, 'window_start_TR': np.int64(307), 'mean_anxiety': np.float64(0.122768046640625), 'mean_scaled_anxiety': np.float64(0.36928391592842086), 'median_anxiety': np.float64(-0.0222509866927083), 'median_scaled_anxiety': np.float64(0.3253118825140616)}
# DEBUG ROW: {'window_start_index': 312, 'window_start_TR': np.int64(312), 'mean_anxiety': np.float64(-0.014960114470486086), 'mean_scaled_anxiety': np.float64(0.32752258872004275), 'median_anxiety': np.float64(-0.0476003200260416), 'median_scaled_anxiety': np.float64(0.31762556916095186)}
# DEBUG ROW: {'window_start_index': 317, 'window_start_TR': np.int64(317), 'mean_anxiety': np.float64(-0.02827928669270831), 'mean_scaled_anxiety': np.float64(0.3234840079038201), 'median_anxiety': np.float64(-0.04131748669270825), 'median_scaled_anxiety': np.float64(0.3195306222489501)}
# DEBUG ROW: {'window_start_index': 322, 'window_start_TR': np.int64(322), 'mean_anxiety': np.float64(0.002641552196180574), 'mean_scaled_anxiety': np.float64(0.33285968866495863), 'median_anxiety': np.float64(-0.0222509866927083), 'median_scaled_anxiety': np.float64(0.3253118825140616)}
# DEBUG ROW: {'window_start_index': 327, 'window_start_TR': np.int64(327), 'mean_anxiety': np.float64(0.031242507751736124), 'mean_scaled_anxiety': np.float64(0.34153194460587866), 'median_anxiety': np.float64(0.0241321799739583), 'median_scaled_anxiety': np.float64(0.3393759822922089)}
# DEBUG ROW: {'window_start_index': 332, 'window_start_TR': np.int64(332), 'mean_anxiety': np.float64(0.04865336886284723), 'mean_scaled_anxiety': np.float64(0.3468111893295061), 'median_anxiety': np.float64(0.052343846640624955), 'median_scaled_anxiety': np.float64(0.34793019976854545)}
# DEBUG ROW: {'window_start_index': 337, 'window_start_TR': np.int64(337), 'mean_anxiety': np.float64(0.07270495219618055), 'mean_scaled_anxiety': np.float64(0.3541040046358297), 'median_anxiety': np.float64(0.06836384664062495), 'median_scaled_anxiety': np.float64(0.35278771370382905)}
# DEBUG ROW: {'window_start_index': 342, 'window_start_TR': np.int64(342), 'mean_anxiety': np.float64(0.13573503552951388), 'mean_scaled_anxiety': np.float64(0.373215709263405), 'median_anxiety': np.float64(0.0913976799739583), 'median_scaled_anxiety': np.float64(0.35977193133177343)}
# DEBUG ROW: {'window_start_index': 347, 'window_start_TR': np.int64(347), 'mean_anxiety': np.float64(0.16887440219618058), 'mean_scaled_anxiety': np.float64(0.3832640822590236), 'median_anxiety': np.float64(0.11664084664062495), 'median_scaled_anxiety': np.float64(0.3674260532951955)}
# DEBUG ROW: {'window_start_index': 352, 'window_start_TR': np.int64(352), 'mean_anxiety': np.float64(0.10546143552951387), 'mean_scaled_anxiety': np.float64(0.364036281431245), 'median_anxiety': np.float64(0.07963917997395831), 'median_scaled_anxiety': np.float64(0.3562065706820835)}
# DEBUG ROW: {'window_start_index': 357, 'window_start_TR': np.int64(357), 'mean_anxiety': np.float64(0.03724168552951389), 'mean_scaled_anxiety': np.float64(0.34335098890399357), 'median_anxiety': np.float64(0.06405984664062495), 'median_scaled_anxiety': np.float64(0.35148267375517356)}
# DEBUG ROW: {'window_start_index': 362, 'window_start_TR': np.int64(362), 'mean_anxiety': np.float64(-0.02985543113715278), 'mean_scaled_anxiety': np.float64(0.3230060963181203), 'median_anxiety': np.float64(0.05772834664062495), 'median_scaled_anxiety': np.float64(0.34956286417457133)}
# DEBUG ROW: {'window_start_index': 367, 'window_start_TR': np.int64(367), 'mean_anxiety': np.float64(-0.10599574224826387), 'mean_scaled_anxiety': np.float64(0.2999191660897147), 'median_anxiety': np.float64(0.0024288466406250505), 'median_scaled_anxiety': np.float64(0.33279519302199834)}
# DEBUG ROW: {'window_start_index': 372, 'window_start_TR': np.int64(372), 'mean_anxiety': np.float64(-0.17372759224826387), 'mean_scaled_anxiety': np.float64(0.2793818124544123), 'median_anxiety': np.float64(0.0024288466406250505), 'median_scaled_anxiety': np.float64(0.33279519302199834)}
# DEBUG ROW: {'window_start_index': 377, 'window_start_TR': np.int64(377), 'mean_anxiety': np.float64(-0.2329231422482639), 'mean_scaled_anxiety': np.float64(0.2614327981577967), 'median_anxiety': np.float64(-0.19025015335937495), 'median_scaled_anxiety': np.float64(0.2743719141495561)}
# DEBUG ROW: {'window_start_index': 382, 'window_start_TR': np.int64(382), 'mean_anxiety': np.float64(-0.28239870335937495), 'mean_scaled_anxiety': np.float64(0.24643103613824602), 'median_anxiety': np.float64(-0.4921181533593749), 'median_scaled_anxiety': np.float64(0.182840826970017)}
# DEBUG ROW: {'window_start_index': 387, 'window_start_TR': np.int64(387), 'mean_anxiety': np.float64(-0.3832870700260417), 'mean_scaled_anxiety': np.float64(0.2158401093597602), 'median_anxiety': np.float64(-0.595847153359375), 'median_scaled_anxiety': np.float64(0.15138857584685583)}
# DEBUG ROW: {'window_start_index': 392, 'window_start_TR': np.int64(392), 'mean_anxiety': np.float64(-0.48099716447048607), 'mean_scaled_anxiety': np.float64(0.18621288430471816), 'median_anxiety': np.float64(-0.6651474866927083), 'median_scaled_anxiety': np.float64(0.13037563359426713)}
# DEBUG ROW: {'window_start_index': 397, 'window_start_TR': np.int64(397), 'mean_anxiety': np.float64(-0.5774254589149305), 'mean_scaled_anxiety': np.float64(0.1569743210076191), 'median_anxiety': np.float64(-0.7530619866927084), 'median_scaled_anxiety': np.float64(0.103718585600291)}
# DEBUG ROW: {'window_start_index': 402, 'window_start_TR': np.int64(402), 'mean_anxiety': np.float64(-0.7046592866927083), 'mean_scaled_anxiety': np.float64(0.11839503939276019), 'median_anxiety': np.float64(-0.7819754866927082), 'median_scaled_anxiety': np.float64(0.09495156130766774)}
# DEBUG ROW: {'window_start_index': 407, 'window_start_TR': np.int64(407), 'mean_anxiety': np.float64(-0.8239400033593752), 'mean_scaled_anxiety': np.float64(0.08222726514688265), 'median_anxiety': np.float64(-0.827384153359375), 'median_scaled_anxiety': np.float64(0.08118294513313686)}
# DEBUG ROW: {'window_start_index': 412, 'window_start_TR': np.int64(412), 'mean_anxiety': np.float64(-0.863615325581597), 'mean_scaled_anxiety': np.float64(0.07019708845641354), 'median_anxiety': np.float64(-0.8811744866927084), 'median_scaled_anxiety': np.float64(0.0648728768590906)}
# DEBUG ROW: {'window_start_index': 417, 'window_start_TR': np.int64(417), 'mean_anxiety': np.float64(-0.8772195089149305), 'mean_scaled_anxiety': np.float64(0.06607208782471437), 'median_anxiety': np.float64(-0.8811744866927084), 'median_scaled_anxiety': np.float64(0.0648728768590906)}
# DEBUG ROW: {'window_start_index': 422, 'window_start_TR': np.int64(422), 'mean_anxiety': np.float64(-0.8684432255815971), 'mean_scaled_anxiety': np.float64(0.0687331938541566), 'median_anxiety': np.float64(-0.8811744866927084), 'median_scaled_anxiety': np.float64(0.0648728768590906)}
# DEBUG ROW: {'window_start_index': 427, 'window_start_TR': np.int64(427), 'mean_anxiety': np.float64(-0.835966603359375), 'mean_scaled_anxiety': np.float64(0.078580612394443), 'median_anxiety': np.float64(-0.8804969866927084), 'median_scaled_anxiety': np.float64(0.0650783054290753)}
# DEBUG ROW: {'window_start_index': 432, 'window_start_TR': np.int64(432), 'mean_anxiety': np.float64(-0.7492420700260418), 'mean_scaled_anxiety': np.float64(0.1048768439298763), 'median_anxiety': np.float64(-0.8533791533593751), 'median_scaled_anxiety': np.float64(0.07330085557335536)}
# DEBUG ROW: {'window_start_index': 437, 'window_start_TR': np.int64(437), 'mean_anxiety': np.float64(-0.6602351755815973), 'mean_scaled_anxiety': np.float64(0.13186512296234898), 'median_anxiety': np.float64(-0.8533791533593751), 'median_scaled_anxiety': np.float64(0.07330085557335536)}
# DEBUG ROW: {'window_start_index': 442, 'window_start_TR': np.int64(442), 'mean_anxiety': np.float64(-0.515510342248264), 'mean_scaled_anxiety': np.float64(0.17574795034676072), 'median_anxiety': np.float64(-0.8533791533593751), 'median_scaled_anxiety': np.float64(0.07330085557335536)}
# DEBUG ROW: {'window_start_index': 447, 'window_start_TR': np.int64(447), 'mean_anxiety': np.float64(-0.2621459311371528), 'mean_scaled_anxiety': np.float64(0.25257199264870617), 'median_anxiety': np.float64(-0.7150424866927083), 'median_scaled_anxiety': np.float64(0.1152466911597491)}
# DEBUG ROW: {'window_start_index': 452, 'window_start_TR': np.int64(452), 'mean_anxiety': np.float64(0.005412646640625004), 'mean_scaled_anxiety': np.float64(0.33369992773361495), 'median_anxiety': np.float64(-0.6209236533593749), 'median_scaled_anxiety': np.float64(0.14378498981700935)}
# DEBUG ROW: {'window_start_index': 457, 'window_start_TR': np.int64(457), 'mean_anxiety': np.float64(0.26450884664062496), 'mean_scaled_anxiety': np.float64(0.41226193785090887), 'median_anxiety': np.float64(-0.15357815335937494), 'median_scaled_anxiety': np.float64(0.2854914366860556)}
# DEBUG ROW: {'window_start_index': 462, 'window_start_TR': np.int64(462), 'mean_anxiety': np.float64(0.5211907133072916), 'mean_scaled_anxiety': np.float64(0.49009188443442714), 'median_anxiety': np.float64(0.3041876799739583), 'median_scaled_anxiety': np.float64(0.4242931791650453)}
# DEBUG ROW: {'window_start_index': 467, 'window_start_TR': np.int64(467), 'mean_anxiety': np.float64(0.7720712410850694), 'mean_scaled_anxiety': np.float64(0.5661627745575157), 'median_anxiety': np.float64(0.49278434664062504), 'median_scaled_anxiety': np.float64(0.4814786308804876)}
# DEBUG ROW: {'window_start_index': 472, 'window_start_TR': np.int64(472), 'mean_anxiety': np.float64(1.012785235529514), 'mean_scaled_anxiety': np.float64(0.6391510131612416), 'median_anxiety': np.float64(1.8745671799739587), 'median_scaled_anxiety': np.float64(0.900456743767656)}
# DEBUG ROW: {'window_start_index': 477, 'window_start_TR': np.int64(477), 'mean_anxiety': np.float64(1.2457396521961805), 'mean_scaled_anxiety': np.float64(0.7097864267220542), 'median_anxiety': np.float64(1.9612966799739582), 'median_scaled_anxiety': np.float64(0.9267544812739098)}
# DEBUG ROW: {'window_start_index': 482, 'window_start_TR': np.int64(482), 'mean_anxiety': np.float64(1.469718424418403), 'mean_scaled_anxiety': np.float64(0.7777002848542125), 'median_anxiety': np.float64(1.9650156799739582), 'median_scaled_anxiety': np.float64(0.9278821400957151)}
# DEBUG ROW: {'window_start_index': 487, 'window_start_TR': np.int64(487), 'mean_anxiety': np.float64(1.6243573188628475), 'mean_scaled_anxiety': np.float64(0.8245892102412756), 'median_anxiety': np.float64(1.9650156799739582), 'median_scaled_anxiety': np.float64(0.9278821400957151)}
# DEBUG ROW: {'window_start_index': 492, 'window_start_TR': np.int64(492), 'mean_anxiety': np.float64(1.647459496640625), 'mean_scaled_anxiety': np.float64(0.831594150971048), 'median_anxiety': np.float64(1.9650156799739582), 'median_scaled_anxiety': np.float64(0.9278821400957151)}
# DEBUG ROW: {'window_start_index': 497, 'window_start_TR': np.int64(497), 'mean_anxiety': np.float64(1.6274617133072917), 'mean_scaled_anxiety': np.float64(0.8255305110698963), 'median_anxiety': np.float64(1.9650156799739582), 'median_scaled_anxiety': np.float64(0.9278821400957151)}
# DEBUG ROW: {'window_start_index': 502, 'window_start_TR': np.int64(502), 'mean_anxiety': np.float64(1.5396153244184025), 'mean_scaled_anxiety': np.float64(0.7988941154274415), 'median_anxiety': np.float64(1.9650156799739582), 'median_scaled_anxiety': np.float64(0.9278821400957151)}
# DEBUG ROW: {'window_start_index': 507, 'window_start_TR': np.int64(507), 'mean_anxiety': np.float64(1.3743774077517361), 'mean_scaled_anxiety': np.float64(0.7487914011424491), 'median_anxiety': np.float64(1.9614253466406248), 'median_scaled_anxiety': np.float64(0.9267934950146302)}
# DEBUG ROW: {'window_start_index': 512, 'window_start_TR': np.int64(512), 'mean_anxiety': np.float64(1.1992995910850694), 'mean_scaled_anxiety': np.float64(0.6957050756607153), 'median_anxiety': np.float64(1.8851446799739584), 'median_scaled_anxiety': np.float64(0.9036640067920295)}
# DEBUG ROW: {'window_start_index': 517, 'window_start_TR': np.int64(517), 'mean_anxiety': np.float64(1.0298188521961804), 'mean_scaled_anxiety': np.float64(0.6443158714837519), 'median_anxiety': np.float64(0.7883318466406251), 'median_scaled_anxiety': np.float64(0.5710932438510403)}
# DEBUG ROW: {'window_start_index': 522, 'window_start_TR': np.int64(522), 'mean_anxiety': np.float64(0.9362001910850695), 'mean_scaled_anxiety': np.float64(0.615929232847683), 'median_anxiety': np.float64(0.7338475133072917), 'median_scaled_anxiety': np.float64(0.5545727439495853)}
# ✅ Saved: LessonLearned_sliding_windows_csv/sub-S32_anxiety_windows.csv with 91 windows
# 📊 Columns: ['window_start_index', 'window_start_TR', 'mean_anxiety', 'mean_scaled_anxiety', 'median_anxiety', 'median_scaled_anxiety', 'binned_by_mean', 'binned_by_median']
# 📊 Bin counts (mean):
# binned_by_mean
# medium    53
# high      25
# low       13
# Name: count, dtype: int64
# 📊 Bin counts (median):
# binned_by_median
# medium    52
# low       20
# high      19
# Name: count, dtype: int64

# %% [markdown]
# It seems like it is best to bin by mean anxiety value

# %% [markdown]
# # Calculating functional connectivity

# %% [markdown]
# ### ROI Time Series

# %% [markdown]
# We are going to start with doing this just for LessonLearned because it has better sample spreads with low vs medium vs high

# %%
# Extract ROI time series for every subject 

import os
import numpy as np
from nilearn.input_data import NiftiLabelsMasker
from nilearn import datasets

bold_dir = "LessonLearned_MNI_bold"    
output_dir = "roi_timeseries"
t_r = 1.2999999523162842
os.makedirs(output_dir, exist_ok=True)

# load schaefer atlas 
atlas = datasets.fetch_atlas_schaefer_2018(n_rois=100, yeo_networks=7)
atlas_img = atlas.maps

# setup masker 
masker = NiftiLabelsMasker(labels_img=atlas_img, standardize=True, t_r=t_r)

# loop through BOLD files 
for fname in os.listdir(bold_dir):
    if "space-MNI" in fname and fname.endswith((".nii", ".nii.gz")):
        subj = fname.split("_")[0] 
        bold_path = os.path.join(bold_dir, fname)
        out_path = os.path.join(output_dir, f"{subj}.npy")

        try:
            print(f"Extracting ROI time series for {subj}")
            roi_ts = masker.fit_transform(bold_path)
            np.save(out_path, roi_ts)
            print(f"Saved: {out_path} — shape: {roi_ts.shape}")
        except Exception as e:
            print(f"Error for {subj}: {e}")
# Out:
# [get_dataset_dir] Dataset found in /Users/emmasombers/nilearn_data/schaefer_2018
# Extracting ROI time series for sub-S01
# Saved: roi_timeseries/sub-S01.npy — shape: (665, 100)
# Extracting ROI time series for sub-S19
# Saved: roi_timeseries/sub-S19.npy — shape: (668, 100)
# Extracting ROI time series for sub-S23
# Saved: roi_timeseries/sub-S23.npy — shape: (668, 100)
# Extracting ROI time series for sub-S20
# Saved: roi_timeseries/sub-S20.npy — shape: (668, 100)
# Extracting ROI time series for sub-S22
# Saved: roi_timeseries/sub-S22.npy — shape: (668, 100)
# Extracting ROI time series for sub-S27
# Saved: roi_timeseries/sub-S27.npy — shape: (670, 100)
# Extracting ROI time series for sub-S02
# Saved: roi_timeseries/sub-S02.npy — shape: (668, 100)
# Extracting ROI time series for sub-S05
# Saved: roi_timeseries/sub-S05.npy — shape: (670, 100)
# Extracting ROI time series for sub-S17
# Saved: roi_timeseries/sub-S17.npy — shape: (668, 100)
# Extracting ROI time series for sub-S32
# Saved: roi_timeseries/sub-S32.npy — shape: (668, 100)
# Extracting ROI time series for sub-S03
# Saved: roi_timeseries/sub-S03.npy — shape: (669, 100)
# Extracting ROI time series for sub-S21
# Saved: roi_timeseries/sub-S21.npy — shape: (668, 100)
# Extracting ROI time series for sub-S08
# Saved: roi_timeseries/sub-S08.npy — shape: (672, 100)
# Extracting ROI time series for sub-S14
# Saved: roi_timeseries/sub-S14.npy — shape: (669, 100)
# Extracting ROI time series for sub-S13
# Saved: roi_timeseries/sub-S13.npy — shape: (668, 100)
# Extracting ROI time series for sub-S31
# Saved: roi_timeseries/sub-S31.npy — shape: (668, 100)
# Extracting ROI time series for sub-S24
# Saved: roi_timeseries/sub-S24.npy — shape: (672, 100)
# Extracting ROI time series for sub-S09
# Saved: roi_timeseries/sub-S09.npy — shape: (668, 100)
# Extracting ROI time series for sub-S04
# Saved: roi_timeseries/sub-S04.npy — shape: (668, 100)
# Extracting ROI time series for sub-S30
# Saved: roi_timeseries/sub-S30.npy — shape: (692, 100)
# Extracting ROI time series for sub-S06
# Saved: roi_timeseries/sub-S06.npy — shape: (668, 100)
# Extracting ROI time series for sub-S25
# Saved: roi_timeseries/sub-S25.npy — shape: (668, 100)
# Extracting ROI time series for sub-S10
# Saved: roi_timeseries/sub-S10.npy — shape: (668, 100)
# Extracting ROI time series for sub-S15
# Saved: roi_timeseries/sub-S15.npy — shape: (671, 100)
# Extracting ROI time series for sub-S29
# Saved: roi_timeseries/sub-S29.npy — shape: (669, 100)
# Extracting ROI time series for sub-S07
# Saved: roi_timeseries/sub-S07.npy — shape: (669, 100)
# Extracting ROI time series for sub-S11
# Saved: roi_timeseries/sub-S11.npy — shape: (668, 100)
# Extracting ROI time series for sub-S16
# Saved: roi_timeseries/sub-S16.npy — shape: (668, 100)
# Extracting ROI time series for sub-S26
# Saved: roi_timeseries/sub-S26.npy — shape: (668, 100)
# Extracting ROI time series for sub-S28
# Saved: roi_timeseries/sub-S28.npy — shape: (669, 100)

# %% [markdown]
# ### Connectivity Calculation and Label Creation

# %%
import os
import numpy as np
import pandas as pd
from nilearn.connectome import ConnectivityMeasure

roi_dir = "roi_timeseries"  
windows_dir = "LessonLearned_sliding_windows_csv" 
fc_output_dir = "fc_matrices"  
window_size = 60  
os.makedirs(fc_output_dir, exist_ok=True)

# set up what is gonna calculate our functional connectivity 
connectivity = ConnectivityMeasure(kind="correlation")

# loop through subjects 
for fname in os.listdir(roi_dir):
    if not fname.endswith(".npy"):
        continue

    subj = fname.replace(".npy", "") 
    roi_path = os.path.join(roi_dir, fname)
    window_csv = os.path.join(windows_dir, f"{subj}_anxiety_windows.csv")

    if not os.path.exists(window_csv):
        print(f"No window file for {subj}, skipping.")
        continue

    print(f"\nProcessing {subj}")

    roi_ts = np.load(roi_path)
    windows_df = pd.read_csv(window_csv)

    fc_matrices = []
    output_labels = []

    for _, row in windows_df.iterrows():
        start = int(row["window_start_index"])
        end = start + window_size

        if end > roi_ts.shape[0]:
            continue 

        window_ts = roi_ts[start:end]
        if window_ts.shape[0] != window_size:
            continue 

        # Compute FC matrix
        fc = connectivity.fit_transform([window_ts])[0]  # shape: (100, 100)
        fc_matrices.append(fc)

        # Keep label info for this window
        output_labels.append({
            "window_start_TR": row["window_start_TR"],
            "mean_scaled_anxiety": row["mean_scaled_anxiety"],
            "binned_by_mean": row["binned_by_mean"]
        })

    if len(fc_matrices) == 0:
        print(f"No valid windows for {subj}, skipping save.")
        continue

    np.save(os.path.join(fc_output_dir, f"{subj}_fc.npy"), np.array(fc_matrices))

    labels_df = pd.DataFrame(output_labels)
    labels_df.to_csv(os.path.join(fc_output_dir, f"{subj}_labels.csv"), index=False)

    print(f"Saved: {subj}_fc.npy ({len(fc_matrices)} FCs) and {subj}_labels.csv")
# Out:
# Processing sub-S32
# Saved: sub-S32_fc.npy (91 FCs) and sub-S32_labels.csv
#
# Processing sub-S26
# Saved: sub-S26_fc.npy (91 FCs) and sub-S26_labels.csv
#
# Processing sub-S27
# Saved: sub-S27_fc.npy (91 FCs) and sub-S27_labels.csv
#
# Processing sub-S25
# Saved: sub-S25_fc.npy (91 FCs) and sub-S25_labels.csv
#
# Processing sub-S31
# Saved: sub-S31_fc.npy (91 FCs) and sub-S31_labels.csv
#
# Processing sub-S19
# Saved: sub-S19_fc.npy (91 FCs) and sub-S19_labels.csv
#
# Processing sub-S30
# Saved: sub-S30_fc.npy (91 FCs) and sub-S30_labels.csv
#
# Processing sub-S24
# Saved: sub-S24_fc.npy (91 FCs) and sub-S24_labels.csv
#
# Processing sub-S08
# Saved: sub-S08_fc.npy (91 FCs) and sub-S08_labels.csv
#
# Processing sub-S20
# Saved: sub-S20_fc.npy (91 FCs) and sub-S20_labels.csv
#
# Processing sub-S21
# Saved: sub-S21_fc.npy (91 FCs) and sub-S21_labels.csv
#
# Processing sub-S09
# Saved: sub-S09_fc.npy (91 FCs) and sub-S09_labels.csv
#
# Processing sub-S23
# Saved: sub-S23_fc.npy (91 FCs) and sub-S23_labels.csv
#
# Processing sub-S22
# Saved: sub-S22_fc.npy (91 FCs) and sub-S22_labels.csv
#
# Processing sub-S13
# Saved: sub-S13_fc.npy (91 FCs) and sub-S13_labels.csv
#
# Processing sub-S07
# Saved: sub-S07_fc.npy (91 FCs) and sub-S07_labels.csv
#
# Processing sub-S06
# Saved: sub-S06_fc.npy (91 FCs) and sub-S06_labels.csv
#
# Processing sub-S04
# Saved: sub-S04_fc.npy (91 FCs) and sub-S04_labels.csv
#
# Processing sub-S10
# Saved: sub-S10_fc.npy (91 FCs) and sub-S10_labels.csv
#
# Processing sub-S11
# Saved: sub-S11_fc.npy (91 FCs) and sub-S11_labels.csv
#
# Processing sub-S05
# Saved: sub-S05_fc.npy (91 FCs) and sub-S05_labels.csv
#
# Processing sub-S29
# Saved: sub-S29_fc.npy (91 FCs) and sub-S29_labels.csv
#
# Processing sub-S01
# Saved: sub-S01_fc.npy (91 FCs) and sub-S01_labels.csv
#
# Processing sub-S15
# Saved: sub-S15_fc.npy (91 FCs) and sub-S15_labels.csv
#
# Processing sub-S14
# Saved: sub-S14_fc.npy (91 FCs) and sub-S14_labels.csv
#
# Processing sub-S28
# Saved: sub-S28_fc.npy (91 FCs) and sub-S28_labels.csv
#
# Processing sub-S16
# Saved: sub-S16_fc.npy (91 FCs) and sub-S16_labels.csv
#
# Processing sub-S02
# Saved: sub-S02_fc.npy (91 FCs) and sub-S02_labels.csv
#
# Processing sub-S03
# Saved: sub-S03_fc.npy (91 FCs) and sub-S03_labels.csv
#
# Processing sub-S17
# Saved: sub-S17_fc.npy (91 FCs) and sub-S17_labels.csv

# %%
# add a column to the labels splitting it 0-0.5 and 0.5-1 

import os 
import pandas as pd 

label_dir = "fc_matrices"

for fname in os.listdir(label_dir):
    if fname.endswith("_labels.csv"):
        fpath = os.path.join(label_dir, fname)
        df = pd.read_csv(fpath)

        # new bin column for low/high binary classification 
        df["binned_0.5"] = df["mean_scaled_anxiety"].apply(lambda x: "low" if x < 0.5 else "high")

        # save file 
        df.to_csv(fpath, index=False)
        print(f"Updated {fname}")
# Out:
# Updated sub-S05_labels.csv
# Updated sub-S32_labels.csv
# Updated sub-S19_labels.csv
# Updated sub-S08_labels.csv
# Updated sub-S23_labels.csv
# Updated sub-S14_labels.csv
# Updated sub-S11_labels.csv
# Updated sub-S26_labels.csv
# Updated sub-S30_labels.csv
# Updated sub-S07_labels.csv
# Updated sub-S16_labels.csv
# Updated sub-S21_labels.csv
# Updated sub-S24_labels.csv
# Updated sub-S13_labels.csv
# Updated sub-S29_labels.csv
# Updated sub-S02_labels.csv
# Updated sub-S10_labels.csv
# Updated sub-S27_labels.csv
# Updated sub-S01_labels.csv
# Updated sub-S04_labels.csv
# Updated sub-S09_labels.csv
# Updated sub-S22_labels.csv
# Updated sub-S15_labels.csv
# Updated sub-S25_labels.csv
# Updated sub-S28_labels.csv
# Updated sub-S03_labels.csv
# Updated sub-S31_labels.csv
# Updated sub-S06_labels.csv
# Updated sub-S17_labels.csv
# Updated sub-S20_labels.csv
