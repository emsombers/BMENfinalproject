# %% [markdown]
# # Functional Connectivity Sliding Window Preprocessing & Calculation

# %% [markdown]
# We are going to make "chunks" of anxiety per subject that we can then align to fMRI data and calculate the functional connectivity. In order to standardize our feature sizes we will make window lengths of fMRI_TR, give a sliding stride, and then calculate mean anixety for the label for each chunk. We will prepare them in two different ways, one that can be used for regression (predicting continuous anxiety values) and one for classification (high vs low anxiety). Note these anxiety values are already z scored. The values from the reviewers are from 0 to 100 and then consensus annotations are calculated from the z scores. We are going to add a minmaxscaled value to each of the CSVs because that is better for some neural networks. Likely regression is best to use the continuous values and then minmax is good for binning for classification.

# %%
# code to add the minmaxscaler values 
import os
import pandas as pd
from sklearn.preprocessing import MinMaxScaler

anxiety_dir = "anxiety_aligned_csv"

for filename in os.listdir(anxiety_dir):
    if filename.endswith(".csv"):
        filepath = os.path.join(anxiety_dir, filename)

        df = pd.read_csv(filepath)

        anxiety_col = df.columns[2]

        scaler = MinMaxScaler()
        df["scaled_anxiety"] = scaler.fit_transform(df[[anxiety_col]])

        df.to_csv(filepath, index=False)
        print(f"Updated: {filename}")
# Out:
# Updated: sub-S25_Chatter_anxiety_aligned.csv
# Updated: sub-S28_LessonLearned_anxiety_aligned.csv
# Updated: sub-S20_Chatter_anxiety_aligned.csv
# Updated: sub-S09_Chatter_anxiety_aligned.csv
# Updated: sub-S25_LessonLearned_anxiety_aligned.csv
# Updated: sub-S11_LessonLearned_anxiety_aligned.csv
# Updated: sub-S02_LessonLearned_anxiety_aligned.csv
# Updated: sub-S10_Chatter_anxiety_aligned.csv
# Updated: sub-S13_LessonLearned_anxiety_aligned.csv
# Updated: sub-S27_LessonLearned_anxiety_aligned.csv
# Updated: sub-S06_Chatter_anxiety_aligned.csv
# Updated: sub-S15_Chatter_anxiety_aligned.csv
# Updated: sub-S03_Chatter_anxiety_aligned.csv
# Updated: sub-S21_Chatter_anxiety_aligned.csv
# Updated: sub-S08_Chatter_anxiety_aligned.csv
# Updated: sub-S29_LessonLearned_anxiety_aligned.csv
# Updated: sub-S24_LessonLearned_anxiety_aligned.csv
# Updated: sub-S24_Chatter_anxiety_aligned.csv
# Updated: sub-S01_LessonLearned_anxiety_aligned.csv
# Updated: sub-S32_Chatter_anxiety_aligned.csv
# Updated: sub-S10_LessonLearned_anxiety_aligned.csv
# Updated: sub-S14_Chatter_anxiety_aligned.csv
# Updated: sub-S03_LessonLearned_anxiety_aligned.csv
# Updated: sub-S02_Chatter_anxiety_aligned.csv
# Updated: sub-S26_LessonLearned_anxiety_aligned.csv
# Updated: sub-S11_Chatter_anxiety_aligned.csv
# Updated: sub-S07_Chatter_anxiety_aligned.csv
# Updated: sub-S08_LessonLearned_anxiety_aligned.csv
# Updated: sub-S19_LessonLearned_anxiety_aligned.csv
# Updated: sub-S04_Chatter_anxiety_aligned.csv
# Updated: sub-S17_Chatter_anxiety_aligned.csv
# Updated: sub-S05_LessonLearned_anxiety_aligned.csv
# Updated: sub-S14_LessonLearned_anxiety_aligned.csv
# Updated: sub-S01_Chatter_anxiety_aligned.csv
# Updated: sub-S20_LessonLearned_anxiety_aligned.csv
# Updated: sub-S28_Chatter_anxiety_aligned.csv
# Updated: sub-S31_LessonLearned_anxiety_aligned.csv
# Updated: sub-S22_LessonLearned_anxiety_aligned.csv
# Updated: sub-S27_Chatter_anxiety_aligned.csv
# Updated: sub-S16_LessonLearned_anxiety_aligned.csv
# Updated: sub-S07_LessonLearned_anxiety_aligned.csv
# Updated: sub-S22_Chatter_anxiety_aligned.csv
# Updated: sub-S16_Chatter_anxiety_aligned.csv
# Updated: sub-S29_Chatter_anxiety_aligned.csv
# Updated: sub-S09_LessonLearned_anxiety_aligned.csv
# Updated: sub-S15_LessonLearned_anxiety_aligned.csv
# Updated: sub-S04_LessonLearned_anxiety_aligned.csv
# Updated: sub-S13_Chatter_anxiety_aligned.csv
# Updated: sub-S30_LessonLearned_anxiety_aligned.csv
# Updated: sub-S21_LessonLearned_anxiety_aligned.csv
# Updated: sub-S05_Chatter_anxiety_aligned.csv
# Updated: sub-S23_Chatter_anxiety_aligned.csv
# Updated: sub-S23_LessonLearned_anxiety_aligned.csv
# Updated: sub-S32_LessonLearned_anxiety_aligned.csv
# Updated: sub-S06_LessonLearned_anxiety_aligned.csv
# Updated: sub-S17_LessonLearned_anxiety_aligned.csv
# Updated: sub-S26_Chatter_anxiety_aligned.csv
# Updated: sub-S19_Chatter_anxiety_aligned.csv
# Updated: sub-S30_Chatter_anxiety_aligned.csv

# %% [markdown]
# # Create the sliding windows

# %% [markdown]
# We are going to create CSVs for each subject that says when the window starts and what the mean z scored anxiety is as well as the binned anxiety level. We will do it based on mean and median.

# %%
from utils.sliding_windows import * 
import os

window_size = 60
step_size = 5 

anxiety_dir = "anxiety_aligned_csv"
output_dir = "Chatter_sliding_windows_csv"


for subj_num in range(1, 33):
    subj_id = f"sub-S{subj_num:02d}"  # ensures sub-S01, sub-S02, ..., sub-S32
    input_file = f"{subj_id}_Chatter_anxiety_aligned.csv"
    input_path = os.path.join(anxiety_dir, input_file)

    if not os.path.exists(input_path):
        print(f"Skipping {subj_id} — no file found.")
        continue

    output_path = os.path.join(output_dir, f"{subj_id}_anxiety_windows.csv")
    create_windows(
        anxiety_csv_path=input_path,
        output_csv_path=output_path,
        window_size=window_size,
        step_size=step_size
    )
# Out:
# DEBUG ROW: {'window_start_index': 72, 'window_start_TR': 72, 'mean_anxiety': -0.27600968669270826, 'mean_scaled_anxiety': 0.2518652537936971, 'median_anxiety': -0.3748003200260416, 'median_scaled_anxiety': 0.2155855203207805}
# DEBUG ROW: {'window_start_index': 77, 'window_start_TR': 77, 'mean_anxiety': -0.287246253359375, 'mean_scaled_anxiety': 0.2477387528283493, 'median_anxiety': -0.3748003200260416, 'median_scaled_anxiety': 0.2155855203207805}
# DEBUG ROW: {'window_start_index': 82, 'window_start_TR': 82, 'mean_anxiety': -0.33720411447048604, 'mean_scaled_anxiety': 0.22939229805998462, 'median_anxiety': -0.4099199866927083, 'median_scaled_anxiety': 0.2026882232458114}
# DEBUG ROW: {'window_start_index': 87, 'window_start_TR': 87, 'mean_anxiety': -0.30059853113715274, 'mean_scaled_anxiety': 0.2428352810852374, 'median_anxiety': -0.4119298200260416, 'median_scaled_anxiety': 0.20195013487449498}
# DEBUG ROW: {'window_start_index': 92, 'window_start_TR': 92, 'mean_anxiety': -0.2651676922482639, 'mean_scaled_anxiety': 0.2558468526101769, 'median_anxiety': -0.4119298200260416, 'median_scaled_anxiety': 0.20195013487449498}
# DEBUG ROW: {'window_start_index': 97, 'window_start_TR': 97, 'mean_anxiety': -0.32305158113715277, 'mean_scaled_anxiety': 0.2345896545296759, 'median_anxiety': -0.44368782002604157, 'median_scaled_anxiety': 0.19028737154605985}
# DEBUG ROW: {'window_start_index': 102, 'window_start_TR': 102, 'mean_anxiety': -0.41148951447048615, 'mean_scaled_anxiety': 0.20211183206848204, 'median_anxiety': -0.48251765335937497, 'median_scaled_anxiety': 0.1760275580738874}
# DEBUG ROW: {'window_start_index': 107, 'window_start_TR': 107, 'mean_anxiety': -0.4475379866927082, 'mean_scaled_anxiety': 0.18887344174543125, 'median_anxiety': -0.4963371533593749, 'median_scaled_anxiety': 0.1709525042979157}
# DEBUG ROW: {'window_start_index': 112, 'window_start_TR': 112, 'mean_anxiety': -0.47121703113715274, 'mean_scaled_anxiety': 0.18017758271151682, 'median_anxiety': -0.514910653359375, 'median_scaled_anxiety': 0.1641315982370589}
# DEBUG ROW: {'window_start_index': 117, 'window_start_TR': 117, 'mean_anxiety': -0.5023492089149306, 'mean_scaled_anxiety': 0.1687446454572504, 'median_anxiety': -0.6051126533593749, 'median_scaled_anxiety': 0.13100594241013308}
# DEBUG ROW: {'window_start_index': 122, 'window_start_TR': 122, 'mean_anxiety': -0.5412860366927084, 'mean_scaled_anxiety': 0.1544455394955317, 'median_anxiety': -0.689954653359375, 'median_scaled_anxiety': 0.0998486854572047}
# DEBUG ROW: {'window_start_index': 127, 'window_start_TR': 127, 'mean_anxiety': -0.5806415755815971, 'mean_scaled_anxiety': 0.1399926666532829, 'median_anxiety': -0.736957653359375, 'median_scaled_anxiety': 0.08258736973434935}
# DEBUG ROW: {'window_start_index': 132, 'window_start_TR': 132, 'mean_anxiety': -0.6044040644704861, 'mean_scaled_anxiety': 0.13126616359875545, 'median_anxiety': -0.753938653359375, 'median_scaled_anxiety': 0.07635129113745545}
# DEBUG ROW: {'window_start_index': 137, 'window_start_TR': 137, 'mean_anxiety': -0.5890206422482639, 'mean_scaled_anxiety': 0.13691554997570513, 'median_anxiety': -0.7496714866927083, 'median_scaled_anxiety': 0.0779183594325723}
# DEBUG ROW: {'window_start_index': 142, 'window_start_TR': 142, 'mean_anxiety': -0.5363470089149305, 'mean_scaled_anxiety': 0.15625934112172946, 'median_anxiety': -0.7124799866927083, 'median_scaled_anxiety': 0.09157651367180325}
# DEBUG ROW: {'window_start_index': 147, 'window_start_TR': 147, 'mean_anxiety': -0.5645055200260417, 'mean_scaled_anxiety': 0.14591844903878967, 'median_anxiety': -0.6918319866927083, 'median_scaled_anxiety': 0.09915925619984435}
# DEBUG ROW: {'window_start_index': 152, 'window_start_TR': 152, 'mean_anxiety': -0.6035489144704861, 'mean_scaled_anxiety': 0.13158020768403508, 'median_anxiety': -0.6918319866927083, 'median_scaled_anxiety': 0.09915925619984435}
# DEBUG ROW: {'window_start_index': 157, 'window_start_TR': 157, 'mean_anxiety': -0.5962447700260418, 'mean_scaled_anxiety': 0.13426257143402756, 'median_anxiety': -0.6918319866927083, 'median_scaled_anxiety': 0.09915925619984435}
# DEBUG ROW: {'window_start_index': 162, 'window_start_TR': 162, 'mean_anxiety': -0.5599799589149306, 'mean_scaled_anxiety': 0.14758040974687145, 'median_anxiety': -0.6819774866927083, 'median_scaled_anxiety': 0.10277820894309225}
# DEBUG ROW: {'window_start_index': 167, 'window_start_TR': 167, 'mean_anxiety': -0.5217798755815972, 'mean_scaled_anxiety': 0.16160895471327888, 'median_anxiety': -0.3912258200260416, 'median_scaled_anxiety': 0.2095534427639062}
# DEBUG ROW: {'window_start_index': 172, 'window_start_TR': 172, 'mean_anxiety': -0.48133895891493056, 'mean_scaled_anxiety': 0.17646042016665453, 'median_anxiety': -0.3277989866927083, 'median_scaled_anxiety': 0.23284622397930935}
# DEBUG ROW: {'window_start_index': 177, 'window_start_TR': 177, 'mean_anxiety': -0.4358550700260416, 'mean_scaled_anxiety': 0.19316385965805682, 'median_anxiety': -0.2974634866927083, 'median_scaled_anxiety': 0.2439865904050838}
# DEBUG ROW: {'window_start_index': 182, 'window_start_TR': 182, 'mean_anxiety': -0.39154509224826384, 'mean_scaled_anxiety': 0.20943619368130909, 'median_anxiety': -0.27841482002604157, 'median_scaled_anxiety': 0.25098199600542337}
# DEBUG ROW: {'window_start_index': 187, 'window_start_TR': 187, 'mean_anxiety': -0.36132893113715275, 'mean_scaled_anxiety': 0.22053273426109235, 'median_anxiety': -0.27841482002604157, 'median_scaled_anxiety': 0.25098199600542337}
# DEBUG ROW: {'window_start_index': 192, 'window_start_TR': 192, 'mean_anxiety': -0.3038363255815971, 'mean_scaled_anxiety': 0.2416462379996628, 'median_anxiety': -0.2710954866927083, 'median_scaled_anxiety': 0.2536699377016446}
# DEBUG ROW: {'window_start_index': 197, 'window_start_TR': 197, 'mean_anxiety': -0.25619842558159717, 'mean_scaled_anxiety': 0.2591407135070519, 'median_anxiety': -0.2710954866927083, 'median_scaled_anxiety': 0.2536699377016446}
# DEBUG ROW: {'window_start_index': 202, 'window_start_TR': 202, 'mean_anxiety': -0.2378761422482638, 'mean_scaled_anxiety': 0.26586936311197656, 'median_anxiety': -0.2710954866927083, 'median_scaled_anxiety': 0.2536699377016446}
# DEBUG ROW: {'window_start_index': 207, 'window_start_TR': 207, 'mean_anxiety': -0.2380330255815972, 'mean_scaled_anxiety': 0.265811749496924, 'median_anxiety': -0.2710954866927083, 'median_scaled_anxiety': 0.2536699377016446}
# DEBUG ROW: {'window_start_index': 212, 'window_start_TR': 212, 'mean_anxiety': -0.25436635891493053, 'mean_scaled_anxiety': 0.25981351909730466, 'median_anxiety': -0.2710954866927083, 'median_scaled_anxiety': 0.2536699377016446}
# DEBUG ROW: {'window_start_index': 217, 'window_start_TR': 217, 'mean_anxiety': -0.26236817558159725, 'mean_scaled_anxiety': 0.25687494318002835, 'median_anxiety': -0.2710954866927083, 'median_scaled_anxiety': 0.2536699377016446}
# DEBUG ROW: {'window_start_index': 222, 'window_start_TR': 222, 'mean_anxiety': -0.27115999224826387, 'mean_scaled_anxiety': 0.25364624877199493, 'median_anxiety': -0.2710954866927083, 'median_scaled_anxiety': 0.2536699377016446}
# DEBUG ROW: {'window_start_index': 227, 'window_start_TR': 227, 'mean_anxiety': -0.2613571811371527, 'mean_scaled_anxiety': 0.2572462193602639, 'median_anxiety': -0.2710954866927083, 'median_scaled_anxiety': 0.2536699377016446}
# DEBUG ROW: {'window_start_index': 232, 'window_start_TR': 232, 'mean_anxiety': -0.23795247558159718, 'mean_scaled_anxiety': 0.26584133056582326, 'median_anxiety': -0.2710954866927083, 'median_scaled_anxiety': 0.2536699377016446}
# DEBUG ROW: {'window_start_index': 237, 'window_start_TR': 237, 'mean_anxiety': -0.20631074780381942, 'mean_scaled_anxiety': 0.27746139424662797, 'median_anxiety': -0.17912132002604164, 'median_scaled_anxiety': 0.28744640152692913}
# DEBUG ROW: {'window_start_index': 242, 'window_start_TR': 242, 'mean_anxiety': -0.16690857558159727, 'mean_scaled_anxiety': 0.2919313926487321, 'median_anxiety': -0.15241332002604163, 'median_scaled_anxiety': 0.2972546099460943}
# DEBUG ROW: {'window_start_index': 247, 'window_start_TR': 247, 'mean_anxiety': -0.1066226644704861, 'mean_scaled_anxiety': 0.31407070599743075, 'median_anxiety': -0.11464382002604165, 'median_scaled_anxiety': 0.31112502809375264}
# DEBUG ROW: {'window_start_index': 252, 'window_start_TR': 252, 'mean_anxiety': -0.07415648669270831, 'mean_scaled_anxiety': 0.3259935395386211, 'median_anxiety': -0.00039398669270835013, 'median_scaled_anxiety': 0.35308197646833017}
# DEBUG ROW: {'window_start_index': 257, 'window_start_TR': 257, 'mean_anxiety': -0.06221531447048611, 'mean_scaled_anxiety': 0.33037879885885096, 'median_anxiety': -0.00039398669270835013, 'median_scaled_anxiety': 0.35308197646833017}
# DEBUG ROW: {'window_start_index': 262, 'window_start_TR': 262, 'mean_anxiety': -0.04201038669270835, 'mean_scaled_anxiety': 0.3377988281661231, 'median_anxiety': 0.02466384664062495, 'median_scaled_anxiety': 0.3622841799978358}
# DEBUG ROW: {'window_start_index': 267, 'window_start_TR': 267, 'mean_anxiety': -0.018956336692708346, 'mean_scaled_anxiety': 0.3462651651178176, 'median_anxiety': 0.10093284664062496, 'median_scaled_anxiety': 0.39029310046815574}
# DEBUG ROW: {'window_start_index': 272, 'window_start_TR': 272, 'mean_anxiety': 0.01472774664062498, 'mean_scaled_anxiety': 0.35863526058516293, 'median_anxiety': 0.10093284664062496, 'median_scaled_anxiety': 0.39029310046815574}
# DEBUG ROW: {'window_start_index': 277, 'window_start_TR': 277, 'mean_anxiety': 0.026454802196180533, 'mean_scaled_anxiety': 0.36294188800136845, 'median_anxiety': 0.10093284664062496, 'median_scaled_anxiety': 0.39029310046815574}
# DEBUG ROW: {'window_start_index': 282, 'window_start_TR': 282, 'mean_anxiety': 0.026448029973958304, 'mean_scaled_anxiety': 0.36293940097998845, 'median_anxiety': 0.10093284664062496, 'median_scaled_anxiety': 0.39029310046815574}
# DEBUG ROW: {'window_start_index': 287, 'window_start_TR': 287, 'mean_anxiety': 0.008324368862847197, 'mean_scaled_anxiety': 0.35628369312106617, 'median_anxiety': 0.10093284664062496, 'median_scaled_anxiety': 0.39029310046815574}
# DEBUG ROW: {'window_start_index': 292, 'window_start_TR': 292, 'mean_anxiety': -0.02719025891493058, 'mean_scaled_anxiety': 0.3432413510822195, 'median_anxiety': 0.10093284664062496, 'median_scaled_anxiety': 0.39029310046815574}
# DEBUG ROW: {'window_start_index': 297, 'window_start_TR': 297, 'mean_anxiety': -0.08479422002604167, 'mean_scaled_anxiety': 0.32208695328578163, 'median_anxiety': 0.06782717997395825, 'median_scaled_anxiety': 0.37813542192531935}
# DEBUG ROW: {'window_start_index': 302, 'window_start_TR': 302, 'mean_anxiety': -0.13915798669270835, 'mean_scaled_anxiety': 0.3021224799475485, 'median_anxiety': -0.303629653359375, 'median_scaled_anxiety': 0.24172213601636225}
# DEBUG ROW: {'window_start_index': 307, 'window_start_TR': 307, 'mean_anxiety': -0.1794369644704861, 'mean_scaled_anxiety': 0.2873304847043493, 'median_anxiety': -0.3173628200260416, 'median_scaled_anxiety': 0.2366787871725028}
# DEBUG ROW: {'window_start_index': 312, 'window_start_TR': 312, 'mean_anxiety': -0.19557969224826388, 'mean_scaled_anxiety': 0.2814022520213221, 'median_anxiety': -0.3173628200260416, 'median_scaled_anxiety': 0.2366787871725028}
# DEBUG ROW: {'window_start_index': 317, 'window_start_TR': 317, 'mean_anxiety': -0.1288762589149305, 'mean_scaled_anxiety': 0.3058983272200349, 'median_anxiety': -0.3173628200260416, 'median_scaled_anxiety': 0.2366787871725028}
# DEBUG ROW: {'window_start_index': 322, 'window_start_TR': 322, 'mean_anxiety': -0.01126429780381943, 'mean_scaled_anxiety': 0.3490899786789432, 'median_anxiety': -0.3173628200260416, 'median_scaled_anxiety': 0.2366787871725028}
# ✅ Saved: Chatter_sliding_windows_csv/sub-S01_anxiety_windows.csv with 51 windows
# 📊 Columns: ['window_start_index', 'window_start_TR', 'mean_anxiety', 'mean_scaled_anxiety', 'median_anxiety', 'median_scaled_anxiety', 'binned_by_mean', 'binned_by_median']
# 📊 Bin counts (mean):
# binned_by_mean
# medium    40
# low       11
# Name: count, dtype: int64
# 📊 Bin counts (median):
# binned_by_median
# medium    40
# low       11
# Name: count, dtype: int64
# DEBUG ROW: {'window_start_index': 72, 'window_start_TR': 72, 'mean_anxiety': -0.27600968669270826, 'mean_scaled_anxiety': 0.2518652537936971, 'median_anxiety': -0.3748003200260416, 'median_scaled_anxiety': 0.2155855203207805}
# DEBUG ROW: {'window_start_index': 77, 'window_start_TR': 77, 'mean_anxiety': -0.287246253359375, 'mean_scaled_anxiety': 0.2477387528283493, 'median_anxiety': -0.3748003200260416, 'median_scaled_anxiety': 0.2155855203207805}
# DEBUG ROW: {'window_start_index': 82, 'window_start_TR': 82, 'mean_anxiety': -0.33720411447048604, 'mean_scaled_anxiety': 0.22939229805998462, 'median_anxiety': -0.4099199866927083, 'median_scaled_anxiety': 0.2026882232458114}
# DEBUG ROW: {'window_start_index': 87, 'window_start_TR': 87, 'mean_anxiety': -0.30059853113715274, 'mean_scaled_anxiety': 0.2428352810852374, 'median_anxiety': -0.4119298200260416, 'median_scaled_anxiety': 0.20195013487449498}
# DEBUG ROW: {'window_start_index': 92, 'window_start_TR': 92, 'mean_anxiety': -0.2651676922482639, 'mean_scaled_anxiety': 0.2558468526101769, 'median_anxiety': -0.4119298200260416, 'median_scaled_anxiety': 0.20195013487449498}
# DEBUG ROW: {'window_start_index': 97, 'window_start_TR': 97, 'mean_anxiety': -0.32305158113715277, 'mean_scaled_anxiety': 0.2345896545296759, 'median_anxiety': -0.44368782002604157, 'median_scaled_anxiety': 0.19028737154605985}
# DEBUG ROW: {'window_start_index': 102, 'window_start_TR': 102, 'mean_anxiety': -0.41148951447048615, 'mean_scaled_anxiety': 0.20211183206848204, 'median_anxiety': -0.48251765335937497, 'median_scaled_anxiety': 0.1760275580738874}
# DEBUG ROW: {'window_start_index': 107, 'window_start_TR': 107, 'mean_anxiety': -0.4475379866927082, 'mean_scaled_anxiety': 0.18887344174543125, 'median_anxiety': -0.4963371533593749, 'median_scaled_anxiety': 0.1709525042979157}
# DEBUG ROW: {'window_start_index': 112, 'window_start_TR': 112, 'mean_anxiety': -0.47121703113715274, 'mean_scaled_anxiety': 0.18017758271151682, 'median_anxiety': -0.514910653359375, 'median_scaled_anxiety': 0.1641315982370589}
# DEBUG ROW: {'window_start_index': 117, 'window_start_TR': 117, 'mean_anxiety': -0.5023492089149306, 'mean_scaled_anxiety': 0.1687446454572504, 'median_anxiety': -0.6051126533593749, 'median_scaled_anxiety': 0.13100594241013308}
# DEBUG ROW: {'window_start_index': 122, 'window_start_TR': 122, 'mean_anxiety': -0.5412860366927084, 'mean_scaled_anxiety': 0.1544455394955317, 'median_anxiety': -0.689954653359375, 'median_scaled_anxiety': 0.0998486854572047}
# DEBUG ROW: {'window_start_index': 127, 'window_start_TR': 127, 'mean_anxiety': -0.5806415755815971, 'mean_scaled_anxiety': 0.1399926666532829, 'median_anxiety': -0.736957653359375, 'median_scaled_anxiety': 0.08258736973434935}
# DEBUG ROW: {'window_start_index': 132, 'window_start_TR': 132, 'mean_anxiety': -0.6044040644704861, 'mean_scaled_anxiety': 0.13126616359875545, 'median_anxiety': -0.753938653359375, 'median_scaled_anxiety': 0.07635129113745545}
# DEBUG ROW: {'window_start_index': 137, 'window_start_TR': 137, 'mean_anxiety': -0.5890206422482639, 'mean_scaled_anxiety': 0.13691554997570513, 'median_anxiety': -0.7496714866927083, 'median_scaled_anxiety': 0.0779183594325723}
# DEBUG ROW: {'window_start_index': 142, 'window_start_TR': 142, 'mean_anxiety': -0.5363470089149305, 'mean_scaled_anxiety': 0.15625934112172946, 'median_anxiety': -0.7124799866927083, 'median_scaled_anxiety': 0.09157651367180325}
# DEBUG ROW: {'window_start_index': 147, 'window_start_TR': 147, 'mean_anxiety': -0.5645055200260417, 'mean_scaled_anxiety': 0.14591844903878967, 'median_anxiety': -0.6918319866927083, 'median_scaled_anxiety': 0.09915925619984435}
# DEBUG ROW: {'window_start_index': 152, 'window_start_TR': 152, 'mean_anxiety': -0.6035489144704861, 'mean_scaled_anxiety': 0.13158020768403508, 'median_anxiety': -0.6918319866927083, 'median_scaled_anxiety': 0.09915925619984435}
# DEBUG ROW: {'window_start_index': 157, 'window_start_TR': 157, 'mean_anxiety': -0.5962447700260418, 'mean_scaled_anxiety': 0.13426257143402756, 'median_anxiety': -0.6918319866927083, 'median_scaled_anxiety': 0.09915925619984435}
# DEBUG ROW: {'window_start_index': 162, 'window_start_TR': 162, 'mean_anxiety': -0.5599799589149306, 'mean_scaled_anxiety': 0.14758040974687145, 'median_anxiety': -0.6819774866927083, 'median_scaled_anxiety': 0.10277820894309225}
# DEBUG ROW: {'window_start_index': 167, 'window_start_TR': 167, 'mean_anxiety': -0.5217798755815972, 'mean_scaled_anxiety': 0.16160895471327888, 'median_anxiety': -0.3912258200260416, 'median_scaled_anxiety': 0.2095534427639062}
# DEBUG ROW: {'window_start_index': 172, 'window_start_TR': 172, 'mean_anxiety': -0.48133895891493056, 'mean_scaled_anxiety': 0.17646042016665453, 'median_anxiety': -0.3277989866927083, 'median_scaled_anxiety': 0.23284622397930935}
# DEBUG ROW: {'window_start_index': 177, 'window_start_TR': 177, 'mean_anxiety': -0.4358550700260416, 'mean_scaled_anxiety': 0.19316385965805682, 'median_anxiety': -0.2974634866927083, 'median_scaled_anxiety': 0.2439865904050838}
# DEBUG ROW: {'window_start_index': 182, 'window_start_TR': 182, 'mean_anxiety': -0.39154509224826384, 'mean_scaled_anxiety': 0.20943619368130909, 'median_anxiety': -0.27841482002604157, 'median_scaled_anxiety': 0.25098199600542337}
# DEBUG ROW: {'window_start_index': 187, 'window_start_TR': 187, 'mean_anxiety': -0.36132893113715275, 'mean_scaled_anxiety': 0.22053273426109235, 'median_anxiety': -0.27841482002604157, 'median_scaled_anxiety': 0.25098199600542337}
# DEBUG ROW: {'window_start_index': 192, 'window_start_TR': 192, 'mean_anxiety': -0.3038363255815971, 'mean_scaled_anxiety': 0.2416462379996628, 'median_anxiety': -0.2710954866927083, 'median_scaled_anxiety': 0.2536699377016446}
# DEBUG ROW: {'window_start_index': 197, 'window_start_TR': 197, 'mean_anxiety': -0.25619842558159717, 'mean_scaled_anxiety': 0.2591407135070519, 'median_anxiety': -0.2710954866927083, 'median_scaled_anxiety': 0.2536699377016446}
# DEBUG ROW: {'window_start_index': 202, 'window_start_TR': 202, 'mean_anxiety': -0.2378761422482638, 'mean_scaled_anxiety': 0.26586936311197656, 'median_anxiety': -0.2710954866927083, 'median_scaled_anxiety': 0.2536699377016446}
# DEBUG ROW: {'window_start_index': 207, 'window_start_TR': 207, 'mean_anxiety': -0.2380330255815972, 'mean_scaled_anxiety': 0.265811749496924, 'median_anxiety': -0.2710954866927083, 'median_scaled_anxiety': 0.2536699377016446}
# DEBUG ROW: {'window_start_index': 212, 'window_start_TR': 212, 'mean_anxiety': -0.25436635891493053, 'mean_scaled_anxiety': 0.25981351909730466, 'median_anxiety': -0.2710954866927083, 'median_scaled_anxiety': 0.2536699377016446}
# DEBUG ROW: {'window_start_index': 217, 'window_start_TR': 217, 'mean_anxiety': -0.26236817558159725, 'mean_scaled_anxiety': 0.25687494318002835, 'median_anxiety': -0.2710954866927083, 'median_scaled_anxiety': 0.2536699377016446}
# DEBUG ROW: {'window_start_index': 222, 'window_start_TR': 222, 'mean_anxiety': -0.27115999224826387, 'mean_scaled_anxiety': 0.25364624877199493, 'median_anxiety': -0.2710954866927083, 'median_scaled_anxiety': 0.2536699377016446}
# DEBUG ROW: {'window_start_index': 227, 'window_start_TR': 227, 'mean_anxiety': -0.2613571811371527, 'mean_scaled_anxiety': 0.2572462193602639, 'median_anxiety': -0.2710954866927083, 'median_scaled_anxiety': 0.2536699377016446}
# DEBUG ROW: {'window_start_index': 232, 'window_start_TR': 232, 'mean_anxiety': -0.23795247558159718, 'mean_scaled_anxiety': 0.26584133056582326, 'median_anxiety': -0.2710954866927083, 'median_scaled_anxiety': 0.2536699377016446}
# DEBUG ROW: {'window_start_index': 237, 'window_start_TR': 237, 'mean_anxiety': -0.20631074780381942, 'mean_scaled_anxiety': 0.27746139424662797, 'median_anxiety': -0.17912132002604164, 'median_scaled_anxiety': 0.28744640152692913}
# DEBUG ROW: {'window_start_index': 242, 'window_start_TR': 242, 'mean_anxiety': -0.16690857558159727, 'mean_scaled_anxiety': 0.2919313926487321, 'median_anxiety': -0.15241332002604163, 'median_scaled_anxiety': 0.2972546099460943}
# DEBUG ROW: {'window_start_index': 247, 'window_start_TR': 247, 'mean_anxiety': -0.1066226644704861, 'mean_scaled_anxiety': 0.31407070599743075, 'median_anxiety': -0.11464382002604165, 'median_scaled_anxiety': 0.31112502809375264}
# DEBUG ROW: {'window_start_index': 252, 'window_start_TR': 252, 'mean_anxiety': -0.07415648669270831, 'mean_scaled_anxiety': 0.3259935395386211, 'median_anxiety': -0.00039398669270835013, 'median_scaled_anxiety': 0.35308197646833017}
# DEBUG ROW: {'window_start_index': 257, 'window_start_TR': 257, 'mean_anxiety': -0.06221531447048611, 'mean_scaled_anxiety': 0.33037879885885096, 'median_anxiety': -0.00039398669270835013, 'median_scaled_anxiety': 0.35308197646833017}
# DEBUG ROW: {'window_start_index': 262, 'window_start_TR': 262, 'mean_anxiety': -0.04201038669270835, 'mean_scaled_anxiety': 0.3377988281661231, 'median_anxiety': 0.02466384664062495, 'median_scaled_anxiety': 0.3622841799978358}
# DEBUG ROW: {'window_start_index': 267, 'window_start_TR': 267, 'mean_anxiety': -0.018956336692708346, 'mean_scaled_anxiety': 0.3462651651178176, 'median_anxiety': 0.10093284664062496, 'median_scaled_anxiety': 0.39029310046815574}
# DEBUG ROW: {'window_start_index': 272, 'window_start_TR': 272, 'mean_anxiety': 0.01472774664062498, 'mean_scaled_anxiety': 0.35863526058516293, 'median_anxiety': 0.10093284664062496, 'median_scaled_anxiety': 0.39029310046815574}
# DEBUG ROW: {'window_start_index': 277, 'window_start_TR': 277, 'mean_anxiety': 0.026454802196180533, 'mean_scaled_anxiety': 0.36294188800136845, 'median_anxiety': 0.10093284664062496, 'median_scaled_anxiety': 0.39029310046815574}
# DEBUG ROW: {'window_start_index': 282, 'window_start_TR': 282, 'mean_anxiety': 0.026448029973958304, 'mean_scaled_anxiety': 0.36293940097998845, 'median_anxiety': 0.10093284664062496, 'median_scaled_anxiety': 0.39029310046815574}
# DEBUG ROW: {'window_start_index': 287, 'window_start_TR': 287, 'mean_anxiety': 0.008324368862847197, 'mean_scaled_anxiety': 0.35628369312106617, 'median_anxiety': 0.10093284664062496, 'median_scaled_anxiety': 0.39029310046815574}
# DEBUG ROW: {'window_start_index': 292, 'window_start_TR': 292, 'mean_anxiety': -0.02719025891493058, 'mean_scaled_anxiety': 0.3432413510822195, 'median_anxiety': 0.10093284664062496, 'median_scaled_anxiety': 0.39029310046815574}
# DEBUG ROW: {'window_start_index': 297, 'window_start_TR': 297, 'mean_anxiety': -0.08479422002604167, 'mean_scaled_anxiety': 0.32208695328578163, 'median_anxiety': 0.06782717997395825, 'median_scaled_anxiety': 0.37813542192531935}
# DEBUG ROW: {'window_start_index': 302, 'window_start_TR': 302, 'mean_anxiety': -0.13915798669270835, 'mean_scaled_anxiety': 0.3021224799475485, 'median_anxiety': -0.303629653359375, 'median_scaled_anxiety': 0.24172213601636225}
# DEBUG ROW: {'window_start_index': 307, 'window_start_TR': 307, 'mean_anxiety': -0.1794369644704861, 'mean_scaled_anxiety': 0.2873304847043493, 'median_anxiety': -0.3173628200260416, 'median_scaled_anxiety': 0.2366787871725028}
# DEBUG ROW: {'window_start_index': 312, 'window_start_TR': 312, 'mean_anxiety': -0.19557969224826388, 'mean_scaled_anxiety': 0.2814022520213221, 'median_anxiety': -0.3173628200260416, 'median_scaled_anxiety': 0.2366787871725028}
# DEBUG ROW: {'window_start_index': 317, 'window_start_TR': 317, 'mean_anxiety': -0.1288762589149305, 'mean_scaled_anxiety': 0.3058983272200349, 'median_anxiety': -0.3173628200260416, 'median_scaled_anxiety': 0.2366787871725028}
# DEBUG ROW: {'window_start_index': 322, 'window_start_TR': 322, 'mean_anxiety': -0.01126429780381943, 'mean_scaled_anxiety': 0.3490899786789432, 'median_anxiety': -0.3173628200260416, 'median_scaled_anxiety': 0.2366787871725028}
# ✅ Saved: Chatter_sliding_windows_csv/sub-S02_anxiety_windows.csv with 51 windows
# 📊 Columns: ['window_start_index', 'window_start_TR', 'mean_anxiety', 'mean_scaled_anxiety', 'median_anxiety', 'median_scaled_anxiety', 'binned_by_mean', 'binned_by_median']
# 📊 Bin counts (mean):
# binned_by_mean
# medium    40
# low       11
# Name: count, dtype: int64
# 📊 Bin counts (median):
# binned_by_median
# medium    40
# low       11
# Name: count, dtype: int64
# DEBUG ROW: {'window_start_index': 72, 'window_start_TR': 72, 'mean_anxiety': -0.27600968669270826, 'mean_scaled_anxiety': 0.2518652537936971, 'median_anxiety': -0.3748003200260416, 'median_scaled_anxiety': 0.2155855203207805}
# DEBUG ROW: {'window_start_index': 77, 'window_start_TR': 77, 'mean_anxiety': -0.287246253359375, 'mean_scaled_anxiety': 0.2477387528283493, 'median_anxiety': -0.3748003200260416, 'median_scaled_anxiety': 0.2155855203207805}
# DEBUG ROW: {'window_start_index': 82, 'window_start_TR': 82, 'mean_anxiety': -0.33720411447048604, 'mean_scaled_anxiety': 0.22939229805998462, 'median_anxiety': -0.4099199866927083, 'median_scaled_anxiety': 0.2026882232458114}
# DEBUG ROW: {'window_start_index': 87, 'window_start_TR': 87, 'mean_anxiety': -0.30059853113715274, 'mean_scaled_anxiety': 0.2428352810852374, 'median_anxiety': -0.4119298200260416, 'median_scaled_anxiety': 0.20195013487449498}
# DEBUG ROW: {'window_start_index': 92, 'window_start_TR': 92, 'mean_anxiety': -0.2651676922482639, 'mean_scaled_anxiety': 0.2558468526101769, 'median_anxiety': -0.4119298200260416, 'median_scaled_anxiety': 0.20195013487449498}
# DEBUG ROW: {'window_start_index': 97, 'window_start_TR': 97, 'mean_anxiety': -0.32305158113715277, 'mean_scaled_anxiety': 0.2345896545296759, 'median_anxiety': -0.44368782002604157, 'median_scaled_anxiety': 0.19028737154605985}
# DEBUG ROW: {'window_start_index': 102, 'window_start_TR': 102, 'mean_anxiety': -0.41148951447048615, 'mean_scaled_anxiety': 0.20211183206848204, 'median_anxiety': -0.48251765335937497, 'median_scaled_anxiety': 0.1760275580738874}
# DEBUG ROW: {'window_start_index': 107, 'window_start_TR': 107, 'mean_anxiety': -0.4475379866927082, 'mean_scaled_anxiety': 0.18887344174543125, 'median_anxiety': -0.4963371533593749, 'median_scaled_anxiety': 0.1709525042979157}
# DEBUG ROW: {'window_start_index': 112, 'window_start_TR': 112, 'mean_anxiety': -0.47121703113715274, 'mean_scaled_anxiety': 0.18017758271151682, 'median_anxiety': -0.514910653359375, 'median_scaled_anxiety': 0.1641315982370589}
# DEBUG ROW: {'window_start_index': 117, 'window_start_TR': 117, 'mean_anxiety': -0.5023492089149306, 'mean_scaled_anxiety': 0.1687446454572504, 'median_anxiety': -0.6051126533593749, 'median_scaled_anxiety': 0.13100594241013308}
# DEBUG ROW: {'window_start_index': 122, 'window_start_TR': 122, 'mean_anxiety': -0.5412860366927084, 'mean_scaled_anxiety': 0.1544455394955317, 'median_anxiety': -0.689954653359375, 'median_scaled_anxiety': 0.0998486854572047}
# DEBUG ROW: {'window_start_index': 127, 'window_start_TR': 127, 'mean_anxiety': -0.5806415755815971, 'mean_scaled_anxiety': 0.1399926666532829, 'median_anxiety': -0.736957653359375, 'median_scaled_anxiety': 0.08258736973434935}
# DEBUG ROW: {'window_start_index': 132, 'window_start_TR': 132, 'mean_anxiety': -0.6044040644704861, 'mean_scaled_anxiety': 0.13126616359875545, 'median_anxiety': -0.753938653359375, 'median_scaled_anxiety': 0.07635129113745545}
# DEBUG ROW: {'window_start_index': 137, 'window_start_TR': 137, 'mean_anxiety': -0.5890206422482639, 'mean_scaled_anxiety': 0.13691554997570513, 'median_anxiety': -0.7496714866927083, 'median_scaled_anxiety': 0.0779183594325723}
# DEBUG ROW: {'window_start_index': 142, 'window_start_TR': 142, 'mean_anxiety': -0.5363470089149305, 'mean_scaled_anxiety': 0.15625934112172946, 'median_anxiety': -0.7124799866927083, 'median_scaled_anxiety': 0.09157651367180325}
# DEBUG ROW: {'window_start_index': 147, 'window_start_TR': 147, 'mean_anxiety': -0.5645055200260417, 'mean_scaled_anxiety': 0.14591844903878967, 'median_anxiety': -0.6918319866927083, 'median_scaled_anxiety': 0.09915925619984435}
# DEBUG ROW: {'window_start_index': 152, 'window_start_TR': 152, 'mean_anxiety': -0.6035489144704861, 'mean_scaled_anxiety': 0.13158020768403508, 'median_anxiety': -0.6918319866927083, 'median_scaled_anxiety': 0.09915925619984435}
# DEBUG ROW: {'window_start_index': 157, 'window_start_TR': 157, 'mean_anxiety': -0.5962447700260418, 'mean_scaled_anxiety': 0.13426257143402756, 'median_anxiety': -0.6918319866927083, 'median_scaled_anxiety': 0.09915925619984435}
# DEBUG ROW: {'window_start_index': 162, 'window_start_TR': 162, 'mean_anxiety': -0.5599799589149306, 'mean_scaled_anxiety': 0.14758040974687145, 'median_anxiety': -0.6819774866927083, 'median_scaled_anxiety': 0.10277820894309225}
# DEBUG ROW: {'window_start_index': 167, 'window_start_TR': 167, 'mean_anxiety': -0.5217798755815972, 'mean_scaled_anxiety': 0.16160895471327888, 'median_anxiety': -0.3912258200260416, 'median_scaled_anxiety': 0.2095534427639062}
# DEBUG ROW: {'window_start_index': 172, 'window_start_TR': 172, 'mean_anxiety': -0.48133895891493056, 'mean_scaled_anxiety': 0.17646042016665453, 'median_anxiety': -0.3277989866927083, 'median_scaled_anxiety': 0.23284622397930935}
# DEBUG ROW: {'window_start_index': 177, 'window_start_TR': 177, 'mean_anxiety': -0.4358550700260416, 'mean_scaled_anxiety': 0.19316385965805682, 'median_anxiety': -0.2974634866927083, 'median_scaled_anxiety': 0.2439865904050838}
# DEBUG ROW: {'window_start_index': 182, 'window_start_TR': 182, 'mean_anxiety': -0.39154509224826384, 'mean_scaled_anxiety': 0.20943619368130909, 'median_anxiety': -0.27841482002604157, 'median_scaled_anxiety': 0.25098199600542337}
# DEBUG ROW: {'window_start_index': 187, 'window_start_TR': 187, 'mean_anxiety': -0.36132893113715275, 'mean_scaled_anxiety': 0.22053273426109235, 'median_anxiety': -0.27841482002604157, 'median_scaled_anxiety': 0.25098199600542337}
# DEBUG ROW: {'window_start_index': 192, 'window_start_TR': 192, 'mean_anxiety': -0.3038363255815971, 'mean_scaled_anxiety': 0.2416462379996628, 'median_anxiety': -0.2710954866927083, 'median_scaled_anxiety': 0.2536699377016446}
# DEBUG ROW: {'window_start_index': 197, 'window_start_TR': 197, 'mean_anxiety': -0.25619842558159717, 'mean_scaled_anxiety': 0.2591407135070519, 'median_anxiety': -0.2710954866927083, 'median_scaled_anxiety': 0.2536699377016446}
# DEBUG ROW: {'window_start_index': 202, 'window_start_TR': 202, 'mean_anxiety': -0.2378761422482638, 'mean_scaled_anxiety': 0.26586936311197656, 'median_anxiety': -0.2710954866927083, 'median_scaled_anxiety': 0.2536699377016446}
# DEBUG ROW: {'window_start_index': 207, 'window_start_TR': 207, 'mean_anxiety': -0.2380330255815972, 'mean_scaled_anxiety': 0.265811749496924, 'median_anxiety': -0.2710954866927083, 'median_scaled_anxiety': 0.2536699377016446}
# DEBUG ROW: {'window_start_index': 212, 'window_start_TR': 212, 'mean_anxiety': -0.25436635891493053, 'mean_scaled_anxiety': 0.25981351909730466, 'median_anxiety': -0.2710954866927083, 'median_scaled_anxiety': 0.2536699377016446}
# DEBUG ROW: {'window_start_index': 217, 'window_start_TR': 217, 'mean_anxiety': -0.26236817558159725, 'mean_scaled_anxiety': 0.25687494318002835, 'median_anxiety': -0.2710954866927083, 'median_scaled_anxiety': 0.2536699377016446}
# DEBUG ROW: {'window_start_index': 222, 'window_start_TR': 222, 'mean_anxiety': -0.27115999224826387, 'mean_scaled_anxiety': 0.25364624877199493, 'median_anxiety': -0.2710954866927083, 'median_scaled_anxiety': 0.2536699377016446}
# DEBUG ROW: {'window_start_index': 227, 'window_start_TR': 227, 'mean_anxiety': -0.2613571811371527, 'mean_scaled_anxiety': 0.2572462193602639, 'median_anxiety': -0.2710954866927083, 'median_scaled_anxiety': 0.2536699377016446}
# DEBUG ROW: {'window_start_index': 232, 'window_start_TR': 232, 'mean_anxiety': -0.23795247558159718, 'mean_scaled_anxiety': 0.26584133056582326, 'median_anxiety': -0.2710954866927083, 'median_scaled_anxiety': 0.2536699377016446}
# DEBUG ROW: {'window_start_index': 237, 'window_start_TR': 237, 'mean_anxiety': -0.20631074780381942, 'mean_scaled_anxiety': 0.27746139424662797, 'median_anxiety': -0.17912132002604164, 'median_scaled_anxiety': 0.28744640152692913}
# DEBUG ROW: {'window_start_index': 242, 'window_start_TR': 242, 'mean_anxiety': -0.16690857558159727, 'mean_scaled_anxiety': 0.2919313926487321, 'median_anxiety': -0.15241332002604163, 'median_scaled_anxiety': 0.2972546099460943}
# DEBUG ROW: {'window_start_index': 247, 'window_start_TR': 247, 'mean_anxiety': -0.1066226644704861, 'mean_scaled_anxiety': 0.31407070599743075, 'median_anxiety': -0.11464382002604165, 'median_scaled_anxiety': 0.31112502809375264}
# DEBUG ROW: {'window_start_index': 252, 'window_start_TR': 252, 'mean_anxiety': -0.07415648669270831, 'mean_scaled_anxiety': 0.3259935395386211, 'median_anxiety': -0.00039398669270835013, 'median_scaled_anxiety': 0.35308197646833017}
# DEBUG ROW: {'window_start_index': 257, 'window_start_TR': 257, 'mean_anxiety': -0.06221531447048611, 'mean_scaled_anxiety': 0.33037879885885096, 'median_anxiety': -0.00039398669270835013, 'median_scaled_anxiety': 0.35308197646833017}
# DEBUG ROW: {'window_start_index': 262, 'window_start_TR': 262, 'mean_anxiety': -0.04201038669270835, 'mean_scaled_anxiety': 0.3377988281661231, 'median_anxiety': 0.02466384664062495, 'median_scaled_anxiety': 0.3622841799978358}
# DEBUG ROW: {'window_start_index': 267, 'window_start_TR': 267, 'mean_anxiety': -0.018956336692708346, 'mean_scaled_anxiety': 0.3462651651178176, 'median_anxiety': 0.10093284664062496, 'median_scaled_anxiety': 0.39029310046815574}
# DEBUG ROW: {'window_start_index': 272, 'window_start_TR': 272, 'mean_anxiety': 0.01472774664062498, 'mean_scaled_anxiety': 0.35863526058516293, 'median_anxiety': 0.10093284664062496, 'median_scaled_anxiety': 0.39029310046815574}
# DEBUG ROW: {'window_start_index': 277, 'window_start_TR': 277, 'mean_anxiety': 0.026454802196180533, 'mean_scaled_anxiety': 0.36294188800136845, 'median_anxiety': 0.10093284664062496, 'median_scaled_anxiety': 0.39029310046815574}
# DEBUG ROW: {'window_start_index': 282, 'window_start_TR': 282, 'mean_anxiety': 0.026448029973958304, 'mean_scaled_anxiety': 0.36293940097998845, 'median_anxiety': 0.10093284664062496, 'median_scaled_anxiety': 0.39029310046815574}
# DEBUG ROW: {'window_start_index': 287, 'window_start_TR': 287, 'mean_anxiety': 0.008324368862847197, 'mean_scaled_anxiety': 0.35628369312106617, 'median_anxiety': 0.10093284664062496, 'median_scaled_anxiety': 0.39029310046815574}
# DEBUG ROW: {'window_start_index': 292, 'window_start_TR': 292, 'mean_anxiety': -0.02719025891493058, 'mean_scaled_anxiety': 0.3432413510822195, 'median_anxiety': 0.10093284664062496, 'median_scaled_anxiety': 0.39029310046815574}
# DEBUG ROW: {'window_start_index': 297, 'window_start_TR': 297, 'mean_anxiety': -0.08479422002604167, 'mean_scaled_anxiety': 0.32208695328578163, 'median_anxiety': 0.06782717997395825, 'median_scaled_anxiety': 0.37813542192531935}
# DEBUG ROW: {'window_start_index': 302, 'window_start_TR': 302, 'mean_anxiety': -0.13915798669270835, 'mean_scaled_anxiety': 0.3021224799475485, 'median_anxiety': -0.303629653359375, 'median_scaled_anxiety': 0.24172213601636225}
# DEBUG ROW: {'window_start_index': 307, 'window_start_TR': 307, 'mean_anxiety': -0.1794369644704861, 'mean_scaled_anxiety': 0.2873304847043493, 'median_anxiety': -0.3173628200260416, 'median_scaled_anxiety': 0.2366787871725028}
# DEBUG ROW: {'window_start_index': 312, 'window_start_TR': 312, 'mean_anxiety': -0.19557969224826388, 'mean_scaled_anxiety': 0.2814022520213221, 'median_anxiety': -0.3173628200260416, 'median_scaled_anxiety': 0.2366787871725028}
# DEBUG ROW: {'window_start_index': 317, 'window_start_TR': 317, 'mean_anxiety': -0.1288762589149305, 'mean_scaled_anxiety': 0.3058983272200349, 'median_anxiety': -0.3173628200260416, 'median_scaled_anxiety': 0.2366787871725028}
# DEBUG ROW: {'window_start_index': 322, 'window_start_TR': 322, 'mean_anxiety': -0.01126429780381943, 'mean_scaled_anxiety': 0.3490899786789432, 'median_anxiety': -0.3173628200260416, 'median_scaled_anxiety': 0.2366787871725028}
# ✅ Saved: Chatter_sliding_windows_csv/sub-S03_anxiety_windows.csv with 51 windows
# 📊 Columns: ['window_start_index', 'window_start_TR', 'mean_anxiety', 'mean_scaled_anxiety', 'median_anxiety', 'median_scaled_anxiety', 'binned_by_mean', 'binned_by_median']
# 📊 Bin counts (mean):
# binned_by_mean
# medium    40
# low       11
# Name: count, dtype: int64
# 📊 Bin counts (median):
# binned_by_median
# medium    40
# low       11
# Name: count, dtype: int64
# DEBUG ROW: {'window_start_index': 72, 'window_start_TR': 72, 'mean_anxiety': -0.27600968669270826, 'mean_scaled_anxiety': 0.2518652537936971, 'median_anxiety': -0.3748003200260416, 'median_scaled_anxiety': 0.2155855203207805}
# DEBUG ROW: {'window_start_index': 77, 'window_start_TR': 77, 'mean_anxiety': -0.287246253359375, 'mean_scaled_anxiety': 0.2477387528283493, 'median_anxiety': -0.3748003200260416, 'median_scaled_anxiety': 0.2155855203207805}
# DEBUG ROW: {'window_start_index': 82, 'window_start_TR': 82, 'mean_anxiety': -0.33720411447048604, 'mean_scaled_anxiety': 0.22939229805998462, 'median_anxiety': -0.4099199866927083, 'median_scaled_anxiety': 0.2026882232458114}
# DEBUG ROW: {'window_start_index': 87, 'window_start_TR': 87, 'mean_anxiety': -0.30059853113715274, 'mean_scaled_anxiety': 0.2428352810852374, 'median_anxiety': -0.4119298200260416, 'median_scaled_anxiety': 0.20195013487449498}
# DEBUG ROW: {'window_start_index': 92, 'window_start_TR': 92, 'mean_anxiety': -0.2651676922482639, 'mean_scaled_anxiety': 0.2558468526101769, 'median_anxiety': -0.4119298200260416, 'median_scaled_anxiety': 0.20195013487449498}
# DEBUG ROW: {'window_start_index': 97, 'window_start_TR': 97, 'mean_anxiety': -0.32305158113715277, 'mean_scaled_anxiety': 0.2345896545296759, 'median_anxiety': -0.44368782002604157, 'median_scaled_anxiety': 0.19028737154605985}
# DEBUG ROW: {'window_start_index': 102, 'window_start_TR': 102, 'mean_anxiety': -0.41148951447048615, 'mean_scaled_anxiety': 0.20211183206848204, 'median_anxiety': -0.48251765335937497, 'median_scaled_anxiety': 0.1760275580738874}
# DEBUG ROW: {'window_start_index': 107, 'window_start_TR': 107, 'mean_anxiety': -0.4475379866927082, 'mean_scaled_anxiety': 0.18887344174543125, 'median_anxiety': -0.4963371533593749, 'median_scaled_anxiety': 0.1709525042979157}
# DEBUG ROW: {'window_start_index': 112, 'window_start_TR': 112, 'mean_anxiety': -0.47121703113715274, 'mean_scaled_anxiety': 0.18017758271151682, 'median_anxiety': -0.514910653359375, 'median_scaled_anxiety': 0.1641315982370589}
# DEBUG ROW: {'window_start_index': 117, 'window_start_TR': 117, 'mean_anxiety': -0.5023492089149306, 'mean_scaled_anxiety': 0.1687446454572504, 'median_anxiety': -0.6051126533593749, 'median_scaled_anxiety': 0.13100594241013308}
# DEBUG ROW: {'window_start_index': 122, 'window_start_TR': 122, 'mean_anxiety': -0.5412860366927084, 'mean_scaled_anxiety': 0.1544455394955317, 'median_anxiety': -0.689954653359375, 'median_scaled_anxiety': 0.0998486854572047}
# DEBUG ROW: {'window_start_index': 127, 'window_start_TR': 127, 'mean_anxiety': -0.5806415755815971, 'mean_scaled_anxiety': 0.1399926666532829, 'median_anxiety': -0.736957653359375, 'median_scaled_anxiety': 0.08258736973434935}
# DEBUG ROW: {'window_start_index': 132, 'window_start_TR': 132, 'mean_anxiety': -0.6044040644704861, 'mean_scaled_anxiety': 0.13126616359875545, 'median_anxiety': -0.753938653359375, 'median_scaled_anxiety': 0.07635129113745545}
# DEBUG ROW: {'window_start_index': 137, 'window_start_TR': 137, 'mean_anxiety': -0.5890206422482639, 'mean_scaled_anxiety': 0.13691554997570513, 'median_anxiety': -0.7496714866927083, 'median_scaled_anxiety': 0.0779183594325723}
# DEBUG ROW: {'window_start_index': 142, 'window_start_TR': 142, 'mean_anxiety': -0.5363470089149305, 'mean_scaled_anxiety': 0.15625934112172946, 'median_anxiety': -0.7124799866927083, 'median_scaled_anxiety': 0.09157651367180325}
# DEBUG ROW: {'window_start_index': 147, 'window_start_TR': 147, 'mean_anxiety': -0.5645055200260417, 'mean_scaled_anxiety': 0.14591844903878967, 'median_anxiety': -0.6918319866927083, 'median_scaled_anxiety': 0.09915925619984435}
# DEBUG ROW: {'window_start_index': 152, 'window_start_TR': 152, 'mean_anxiety': -0.6035489144704861, 'mean_scaled_anxiety': 0.13158020768403508, 'median_anxiety': -0.6918319866927083, 'median_scaled_anxiety': 0.09915925619984435}
# DEBUG ROW: {'window_start_index': 157, 'window_start_TR': 157, 'mean_anxiety': -0.5962447700260418, 'mean_scaled_anxiety': 0.13426257143402756, 'median_anxiety': -0.6918319866927083, 'median_scaled_anxiety': 0.09915925619984435}
# DEBUG ROW: {'window_start_index': 162, 'window_start_TR': 162, 'mean_anxiety': -0.5599799589149306, 'mean_scaled_anxiety': 0.14758040974687145, 'median_anxiety': -0.6819774866927083, 'median_scaled_anxiety': 0.10277820894309225}
# DEBUG ROW: {'window_start_index': 167, 'window_start_TR': 167, 'mean_anxiety': -0.5217798755815972, 'mean_scaled_anxiety': 0.16160895471327888, 'median_anxiety': -0.3912258200260416, 'median_scaled_anxiety': 0.2095534427639062}
# DEBUG ROW: {'window_start_index': 172, 'window_start_TR': 172, 'mean_anxiety': -0.48133895891493056, 'mean_scaled_anxiety': 0.17646042016665453, 'median_anxiety': -0.3277989866927083, 'median_scaled_anxiety': 0.23284622397930935}
# DEBUG ROW: {'window_start_index': 177, 'window_start_TR': 177, 'mean_anxiety': -0.4358550700260416, 'mean_scaled_anxiety': 0.19316385965805682, 'median_anxiety': -0.2974634866927083, 'median_scaled_anxiety': 0.2439865904050838}
# DEBUG ROW: {'window_start_index': 182, 'window_start_TR': 182, 'mean_anxiety': -0.39154509224826384, 'mean_scaled_anxiety': 0.20943619368130909, 'median_anxiety': -0.27841482002604157, 'median_scaled_anxiety': 0.25098199600542337}
# DEBUG ROW: {'window_start_index': 187, 'window_start_TR': 187, 'mean_anxiety': -0.36132893113715275, 'mean_scaled_anxiety': 0.22053273426109235, 'median_anxiety': -0.27841482002604157, 'median_scaled_anxiety': 0.25098199600542337}
# DEBUG ROW: {'window_start_index': 192, 'window_start_TR': 192, 'mean_anxiety': -0.3038363255815971, 'mean_scaled_anxiety': 0.2416462379996628, 'median_anxiety': -0.2710954866927083, 'median_scaled_anxiety': 0.2536699377016446}
# DEBUG ROW: {'window_start_index': 197, 'window_start_TR': 197, 'mean_anxiety': -0.25619842558159717, 'mean_scaled_anxiety': 0.2591407135070519, 'median_anxiety': -0.2710954866927083, 'median_scaled_anxiety': 0.2536699377016446}
# DEBUG ROW: {'window_start_index': 202, 'window_start_TR': 202, 'mean_anxiety': -0.2378761422482638, 'mean_scaled_anxiety': 0.26586936311197656, 'median_anxiety': -0.2710954866927083, 'median_scaled_anxiety': 0.2536699377016446}
# DEBUG ROW: {'window_start_index': 207, 'window_start_TR': 207, 'mean_anxiety': -0.2380330255815972, 'mean_scaled_anxiety': 0.265811749496924, 'median_anxiety': -0.2710954866927083, 'median_scaled_anxiety': 0.2536699377016446}
# DEBUG ROW: {'window_start_index': 212, 'window_start_TR': 212, 'mean_anxiety': -0.25436635891493053, 'mean_scaled_anxiety': 0.25981351909730466, 'median_anxiety': -0.2710954866927083, 'median_scaled_anxiety': 0.2536699377016446}
# DEBUG ROW: {'window_start_index': 217, 'window_start_TR': 217, 'mean_anxiety': -0.26236817558159725, 'mean_scaled_anxiety': 0.25687494318002835, 'median_anxiety': -0.2710954866927083, 'median_scaled_anxiety': 0.2536699377016446}
# DEBUG ROW: {'window_start_index': 222, 'window_start_TR': 222, 'mean_anxiety': -0.27115999224826387, 'mean_scaled_anxiety': 0.25364624877199493, 'median_anxiety': -0.2710954866927083, 'median_scaled_anxiety': 0.2536699377016446}
# DEBUG ROW: {'window_start_index': 227, 'window_start_TR': 227, 'mean_anxiety': -0.2613571811371527, 'mean_scaled_anxiety': 0.2572462193602639, 'median_anxiety': -0.2710954866927083, 'median_scaled_anxiety': 0.2536699377016446}
# DEBUG ROW: {'window_start_index': 232, 'window_start_TR': 232, 'mean_anxiety': -0.23795247558159718, 'mean_scaled_anxiety': 0.26584133056582326, 'median_anxiety': -0.2710954866927083, 'median_scaled_anxiety': 0.2536699377016446}
# DEBUG ROW: {'window_start_index': 237, 'window_start_TR': 237, 'mean_anxiety': -0.20631074780381942, 'mean_scaled_anxiety': 0.27746139424662797, 'median_anxiety': -0.17912132002604164, 'median_scaled_anxiety': 0.28744640152692913}
# DEBUG ROW: {'window_start_index': 242, 'window_start_TR': 242, 'mean_anxiety': -0.16690857558159727, 'mean_scaled_anxiety': 0.2919313926487321, 'median_anxiety': -0.15241332002604163, 'median_scaled_anxiety': 0.2972546099460943}
# DEBUG ROW: {'window_start_index': 247, 'window_start_TR': 247, 'mean_anxiety': -0.1066226644704861, 'mean_scaled_anxiety': 0.31407070599743075, 'median_anxiety': -0.11464382002604165, 'median_scaled_anxiety': 0.31112502809375264}
# DEBUG ROW: {'window_start_index': 252, 'window_start_TR': 252, 'mean_anxiety': -0.07415648669270831, 'mean_scaled_anxiety': 0.3259935395386211, 'median_anxiety': -0.00039398669270835013, 'median_scaled_anxiety': 0.35308197646833017}
# DEBUG ROW: {'window_start_index': 257, 'window_start_TR': 257, 'mean_anxiety': -0.06221531447048611, 'mean_scaled_anxiety': 0.33037879885885096, 'median_anxiety': -0.00039398669270835013, 'median_scaled_anxiety': 0.35308197646833017}
# DEBUG ROW: {'window_start_index': 262, 'window_start_TR': 262, 'mean_anxiety': -0.04201038669270835, 'mean_scaled_anxiety': 0.3377988281661231, 'median_anxiety': 0.02466384664062495, 'median_scaled_anxiety': 0.3622841799978358}
# DEBUG ROW: {'window_start_index': 267, 'window_start_TR': 267, 'mean_anxiety': -0.018956336692708346, 'mean_scaled_anxiety': 0.3462651651178176, 'median_anxiety': 0.10093284664062496, 'median_scaled_anxiety': 0.39029310046815574}
# DEBUG ROW: {'window_start_index': 272, 'window_start_TR': 272, 'mean_anxiety': 0.01472774664062498, 'mean_scaled_anxiety': 0.35863526058516293, 'median_anxiety': 0.10093284664062496, 'median_scaled_anxiety': 0.39029310046815574}
# DEBUG ROW: {'window_start_index': 277, 'window_start_TR': 277, 'mean_anxiety': 0.026454802196180533, 'mean_scaled_anxiety': 0.36294188800136845, 'median_anxiety': 0.10093284664062496, 'median_scaled_anxiety': 0.39029310046815574}
# DEBUG ROW: {'window_start_index': 282, 'window_start_TR': 282, 'mean_anxiety': 0.026448029973958304, 'mean_scaled_anxiety': 0.36293940097998845, 'median_anxiety': 0.10093284664062496, 'median_scaled_anxiety': 0.39029310046815574}
# DEBUG ROW: {'window_start_index': 287, 'window_start_TR': 287, 'mean_anxiety': 0.008324368862847197, 'mean_scaled_anxiety': 0.35628369312106617, 'median_anxiety': 0.10093284664062496, 'median_scaled_anxiety': 0.39029310046815574}
# DEBUG ROW: {'window_start_index': 292, 'window_start_TR': 292, 'mean_anxiety': -0.02719025891493058, 'mean_scaled_anxiety': 0.3432413510822195, 'median_anxiety': 0.10093284664062496, 'median_scaled_anxiety': 0.39029310046815574}
# DEBUG ROW: {'window_start_index': 297, 'window_start_TR': 297, 'mean_anxiety': -0.08479422002604167, 'mean_scaled_anxiety': 0.32208695328578163, 'median_anxiety': 0.06782717997395825, 'median_scaled_anxiety': 0.37813542192531935}
# DEBUG ROW: {'window_start_index': 302, 'window_start_TR': 302, 'mean_anxiety': -0.13915798669270835, 'mean_scaled_anxiety': 0.3021224799475485, 'median_anxiety': -0.303629653359375, 'median_scaled_anxiety': 0.24172213601636225}
# DEBUG ROW: {'window_start_index': 307, 'window_start_TR': 307, 'mean_anxiety': -0.1794369644704861, 'mean_scaled_anxiety': 0.2873304847043493, 'median_anxiety': -0.3173628200260416, 'median_scaled_anxiety': 0.2366787871725028}
# DEBUG ROW: {'window_start_index': 312, 'window_start_TR': 312, 'mean_anxiety': -0.19557969224826388, 'mean_scaled_anxiety': 0.2814022520213221, 'median_anxiety': -0.3173628200260416, 'median_scaled_anxiety': 0.2366787871725028}
# DEBUG ROW: {'window_start_index': 317, 'window_start_TR': 317, 'mean_anxiety': -0.1288762589149305, 'mean_scaled_anxiety': 0.3058983272200349, 'median_anxiety': -0.3173628200260416, 'median_scaled_anxiety': 0.2366787871725028}
# DEBUG ROW: {'window_start_index': 322, 'window_start_TR': 322, 'mean_anxiety': -0.01126429780381943, 'mean_scaled_anxiety': 0.3490899786789432, 'median_anxiety': -0.3173628200260416, 'median_scaled_anxiety': 0.2366787871725028}
# ...
# DEBUG ROW: {'window_start_index': 252, 'window_start_TR': 252, 'mean_anxiety': -0.07415648669270831, 'mean_scaled_anxiety': 0.3259935395386211, 'median_anxiety': -0.00039398669270835013, 'median_scaled_anxiety': 0.35308197646833017}
# DEBUG ROW: {'window_start_index': 257, 'window_start_TR': 257, 'mean_anxiety': -0.06221531447048611, 'mean_scaled_anxiety': 0.33037879885885096, 'median_anxiety': -0.00039398669270835013, 'median_scaled_anxiety': 0.35308197646833017}
# DEBUG ROW: {'window_start_index': 262, 'window_start_TR': 262, 'mean_anxiety': -0.04201038669270835, 'mean_scaled_anxiety': 0.3377988281661231, 'median_anxiety': 0.02466384664062495, 'median_scaled_anxiety': 0.3622841799978358}
# DEBUG ROW: {'window_start_index': 267, 'window_start_TR': 267, 'mean_anxiety': -0.018956336692708346, 'mean_scaled_anxiety': 0.3462651651178176, 'median_anxiety': 0.10093284664062496, 'median_scaled_anxiety': 0.39029310046815574}
# DEBUG ROW: {'window_start_index': 272, 'window_start_TR': 272, 'mean_anxiety': 0.01472774664062498, 'mean_scaled_anxiety': 0.35863526058516293, 'median_anxiety': 0.10093284664062496, 'median_scaled_anxiety': 0.39029310046815574}
# DEBUG ROW: {'window_start_index': 277, 'window_start_TR': 277, 'mean_anxiety': 0.026454802196180533, 'mean_scaled_anxiety': 0.36294188800136845, 'median_anxiety': 0.10093284664062496, 'median_scaled_anxiety': 0.39029310046815574}
# DEBUG ROW: {'window_start_index': 282, 'window_start_TR': 282, 'mean_anxiety': 0.026448029973958304, 'mean_scaled_anxiety': 0.36293940097998845, 'median_anxiety': 0.10093284664062496, 'median_scaled_anxiety': 0.39029310046815574}
# DEBUG ROW: {'window_start_index': 287, 'window_start_TR': 287, 'mean_anxiety': 0.008324368862847197, 'mean_scaled_anxiety': 0.35628369312106617, 'median_anxiety': 0.10093284664062496, 'median_scaled_anxiety': 0.39029310046815574}
# DEBUG ROW: {'window_start_index': 292, 'window_start_TR': 292, 'mean_anxiety': -0.02719025891493058, 'mean_scaled_anxiety': 0.3432413510822195, 'median_anxiety': 0.10093284664062496, 'median_scaled_anxiety': 0.39029310046815574}
# DEBUG ROW: {'window_start_index': 297, 'window_start_TR': 297, 'mean_anxiety': -0.08479422002604167, 'mean_scaled_anxiety': 0.32208695328578163, 'median_anxiety': 0.06782717997395825, 'median_scaled_anxiety': 0.37813542192531935}
# DEBUG ROW: {'window_start_index': 302, 'window_start_TR': 302, 'mean_anxiety': -0.13915798669270835, 'mean_scaled_anxiety': 0.3021224799475485, 'median_anxiety': -0.303629653359375, 'median_scaled_anxiety': 0.24172213601636225}
# DEBUG ROW: {'window_start_index': 307, 'window_start_TR': 307, 'mean_anxiety': -0.1794369644704861, 'mean_scaled_anxiety': 0.2873304847043493, 'median_anxiety': -0.3173628200260416, 'median_scaled_anxiety': 0.2366787871725028}
# DEBUG ROW: {'window_start_index': 312, 'window_start_TR': 312, 'mean_anxiety': -0.19557969224826388, 'mean_scaled_anxiety': 0.2814022520213221, 'median_anxiety': -0.3173628200260416, 'median_scaled_anxiety': 0.2366787871725028}
# DEBUG ROW: {'window_start_index': 317, 'window_start_TR': 317, 'mean_anxiety': -0.1288762589149305, 'mean_scaled_anxiety': 0.3058983272200349, 'median_anxiety': -0.3173628200260416, 'median_scaled_anxiety': 0.2366787871725028}
# DEBUG ROW: {'window_start_index': 322, 'window_start_TR': 322, 'mean_anxiety': -0.01126429780381943, 'mean_scaled_anxiety': 0.3490899786789432, 'median_anxiety': -0.3173628200260416, 'median_scaled_anxiety': 0.2366787871725028}
# ✅ Saved: Chatter_sliding_windows_csv/sub-S30_anxiety_windows.csv with 51 windows
# 📊 Columns: ['window_start_index', 'window_start_TR', 'mean_anxiety', 'mean_scaled_anxiety', 'median_anxiety', 'median_scaled_anxiety', 'binned_by_mean', 'binned_by_median']
# 📊 Bin counts (mean):
# binned_by_mean
# medium    40
# low       11
# Name: count, dtype: int64
# 📊 Bin counts (median):
# binned_by_median
# medium    40
# low       11
# Name: count, dtype: int64
# Skipping sub-S31 — no file found.
# DEBUG ROW: {'window_start_index': 72, 'window_start_TR': 72, 'mean_anxiety': -0.27600968669270826, 'mean_scaled_anxiety': 0.2518652537936971, 'median_anxiety': -0.3748003200260416, 'median_scaled_anxiety': 0.2155855203207805}
# DEBUG ROW: {'window_start_index': 77, 'window_start_TR': 77, 'mean_anxiety': -0.287246253359375, 'mean_scaled_anxiety': 0.2477387528283493, 'median_anxiety': -0.3748003200260416, 'median_scaled_anxiety': 0.2155855203207805}
# DEBUG ROW: {'window_start_index': 82, 'window_start_TR': 82, 'mean_anxiety': -0.33720411447048604, 'mean_scaled_anxiety': 0.22939229805998462, 'median_anxiety': -0.4099199866927083, 'median_scaled_anxiety': 0.2026882232458114}
# DEBUG ROW: {'window_start_index': 87, 'window_start_TR': 87, 'mean_anxiety': -0.30059853113715274, 'mean_scaled_anxiety': 0.2428352810852374, 'median_anxiety': -0.4119298200260416, 'median_scaled_anxiety': 0.20195013487449498}
# DEBUG ROW: {'window_start_index': 92, 'window_start_TR': 92, 'mean_anxiety': -0.2651676922482639, 'mean_scaled_anxiety': 0.2558468526101769, 'median_anxiety': -0.4119298200260416, 'median_scaled_anxiety': 0.20195013487449498}
# DEBUG ROW: {'window_start_index': 97, 'window_start_TR': 97, 'mean_anxiety': -0.32305158113715277, 'mean_scaled_anxiety': 0.2345896545296759, 'median_anxiety': -0.44368782002604157, 'median_scaled_anxiety': 0.19028737154605985}
# DEBUG ROW: {'window_start_index': 102, 'window_start_TR': 102, 'mean_anxiety': -0.41148951447048615, 'mean_scaled_anxiety': 0.20211183206848204, 'median_anxiety': -0.48251765335937497, 'median_scaled_anxiety': 0.1760275580738874}
# DEBUG ROW: {'window_start_index': 107, 'window_start_TR': 107, 'mean_anxiety': -0.4475379866927082, 'mean_scaled_anxiety': 0.18887344174543125, 'median_anxiety': -0.4963371533593749, 'median_scaled_anxiety': 0.1709525042979157}
# DEBUG ROW: {'window_start_index': 112, 'window_start_TR': 112, 'mean_anxiety': -0.47121703113715274, 'mean_scaled_anxiety': 0.18017758271151682, 'median_anxiety': -0.514910653359375, 'median_scaled_anxiety': 0.1641315982370589}
# DEBUG ROW: {'window_start_index': 117, 'window_start_TR': 117, 'mean_anxiety': -0.5023492089149306, 'mean_scaled_anxiety': 0.1687446454572504, 'median_anxiety': -0.6051126533593749, 'median_scaled_anxiety': 0.13100594241013308}
# DEBUG ROW: {'window_start_index': 122, 'window_start_TR': 122, 'mean_anxiety': -0.5412860366927084, 'mean_scaled_anxiety': 0.1544455394955317, 'median_anxiety': -0.689954653359375, 'median_scaled_anxiety': 0.0998486854572047}
# DEBUG ROW: {'window_start_index': 127, 'window_start_TR': 127, 'mean_anxiety': -0.5806415755815971, 'mean_scaled_anxiety': 0.1399926666532829, 'median_anxiety': -0.736957653359375, 'median_scaled_anxiety': 0.08258736973434935}
# DEBUG ROW: {'window_start_index': 132, 'window_start_TR': 132, 'mean_anxiety': -0.6044040644704861, 'mean_scaled_anxiety': 0.13126616359875545, 'median_anxiety': -0.753938653359375, 'median_scaled_anxiety': 0.07635129113745545}
# DEBUG ROW: {'window_start_index': 137, 'window_start_TR': 137, 'mean_anxiety': -0.5890206422482639, 'mean_scaled_anxiety': 0.13691554997570513, 'median_anxiety': -0.7496714866927083, 'median_scaled_anxiety': 0.0779183594325723}
# DEBUG ROW: {'window_start_index': 142, 'window_start_TR': 142, 'mean_anxiety': -0.5363470089149305, 'mean_scaled_anxiety': 0.15625934112172946, 'median_anxiety': -0.7124799866927083, 'median_scaled_anxiety': 0.09157651367180325}
# DEBUG ROW: {'window_start_index': 147, 'window_start_TR': 147, 'mean_anxiety': -0.5645055200260417, 'mean_scaled_anxiety': 0.14591844903878967, 'median_anxiety': -0.6918319866927083, 'median_scaled_anxiety': 0.09915925619984435}
# DEBUG ROW: {'window_start_index': 152, 'window_start_TR': 152, 'mean_anxiety': -0.6035489144704861, 'mean_scaled_anxiety': 0.13158020768403508, 'median_anxiety': -0.6918319866927083, 'median_scaled_anxiety': 0.09915925619984435}
# DEBUG ROW: {'window_start_index': 157, 'window_start_TR': 157, 'mean_anxiety': -0.5962447700260418, 'mean_scaled_anxiety': 0.13426257143402756, 'median_anxiety': -0.6918319866927083, 'median_scaled_anxiety': 0.09915925619984435}
# DEBUG ROW: {'window_start_index': 162, 'window_start_TR': 162, 'mean_anxiety': -0.5599799589149306, 'mean_scaled_anxiety': 0.14758040974687145, 'median_anxiety': -0.6819774866927083, 'median_scaled_anxiety': 0.10277820894309225}
# DEBUG ROW: {'window_start_index': 167, 'window_start_TR': 167, 'mean_anxiety': -0.5217798755815972, 'mean_scaled_anxiety': 0.16160895471327888, 'median_anxiety': -0.3912258200260416, 'median_scaled_anxiety': 0.2095534427639062}
# DEBUG ROW: {'window_start_index': 172, 'window_start_TR': 172, 'mean_anxiety': -0.48133895891493056, 'mean_scaled_anxiety': 0.17646042016665453, 'median_anxiety': -0.3277989866927083, 'median_scaled_anxiety': 0.23284622397930935}
# DEBUG ROW: {'window_start_index': 177, 'window_start_TR': 177, 'mean_anxiety': -0.4358550700260416, 'mean_scaled_anxiety': 0.19316385965805682, 'median_anxiety': -0.2974634866927083, 'median_scaled_anxiety': 0.2439865904050838}
# DEBUG ROW: {'window_start_index': 182, 'window_start_TR': 182, 'mean_anxiety': -0.39154509224826384, 'mean_scaled_anxiety': 0.20943619368130909, 'median_anxiety': -0.27841482002604157, 'median_scaled_anxiety': 0.25098199600542337}
# DEBUG ROW: {'window_start_index': 187, 'window_start_TR': 187, 'mean_anxiety': -0.36132893113715275, 'mean_scaled_anxiety': 0.22053273426109235, 'median_anxiety': -0.27841482002604157, 'median_scaled_anxiety': 0.25098199600542337}
# DEBUG ROW: {'window_start_index': 192, 'window_start_TR': 192, 'mean_anxiety': -0.3038363255815971, 'mean_scaled_anxiety': 0.2416462379996628, 'median_anxiety': -0.2710954866927083, 'median_scaled_anxiety': 0.2536699377016446}
# DEBUG ROW: {'window_start_index': 197, 'window_start_TR': 197, 'mean_anxiety': -0.25619842558159717, 'mean_scaled_anxiety': 0.2591407135070519, 'median_anxiety': -0.2710954866927083, 'median_scaled_anxiety': 0.2536699377016446}
# DEBUG ROW: {'window_start_index': 202, 'window_start_TR': 202, 'mean_anxiety': -0.2378761422482638, 'mean_scaled_anxiety': 0.26586936311197656, 'median_anxiety': -0.2710954866927083, 'median_scaled_anxiety': 0.2536699377016446}
# DEBUG ROW: {'window_start_index': 207, 'window_start_TR': 207, 'mean_anxiety': -0.2380330255815972, 'mean_scaled_anxiety': 0.265811749496924, 'median_anxiety': -0.2710954866927083, 'median_scaled_anxiety': 0.2536699377016446}
# DEBUG ROW: {'window_start_index': 212, 'window_start_TR': 212, 'mean_anxiety': -0.25436635891493053, 'mean_scaled_anxiety': 0.25981351909730466, 'median_anxiety': -0.2710954866927083, 'median_scaled_anxiety': 0.2536699377016446}
# DEBUG ROW: {'window_start_index': 217, 'window_start_TR': 217, 'mean_anxiety': -0.26236817558159725, 'mean_scaled_anxiety': 0.25687494318002835, 'median_anxiety': -0.2710954866927083, 'median_scaled_anxiety': 0.2536699377016446}
# DEBUG ROW: {'window_start_index': 222, 'window_start_TR': 222, 'mean_anxiety': -0.27115999224826387, 'mean_scaled_anxiety': 0.25364624877199493, 'median_anxiety': -0.2710954866927083, 'median_scaled_anxiety': 0.2536699377016446}
# DEBUG ROW: {'window_start_index': 227, 'window_start_TR': 227, 'mean_anxiety': -0.2613571811371527, 'mean_scaled_anxiety': 0.2572462193602639, 'median_anxiety': -0.2710954866927083, 'median_scaled_anxiety': 0.2536699377016446}
# DEBUG ROW: {'window_start_index': 232, 'window_start_TR': 232, 'mean_anxiety': -0.23795247558159718, 'mean_scaled_anxiety': 0.26584133056582326, 'median_anxiety': -0.2710954866927083, 'median_scaled_anxiety': 0.2536699377016446}
# DEBUG ROW: {'window_start_index': 237, 'window_start_TR': 237, 'mean_anxiety': -0.20631074780381942, 'mean_scaled_anxiety': 0.27746139424662797, 'median_anxiety': -0.17912132002604164, 'median_scaled_anxiety': 0.28744640152692913}
# DEBUG ROW: {'window_start_index': 242, 'window_start_TR': 242, 'mean_anxiety': -0.16690857558159727, 'mean_scaled_anxiety': 0.2919313926487321, 'median_anxiety': -0.15241332002604163, 'median_scaled_anxiety': 0.2972546099460943}
# DEBUG ROW: {'window_start_index': 247, 'window_start_TR': 247, 'mean_anxiety': -0.1066226644704861, 'mean_scaled_anxiety': 0.31407070599743075, 'median_anxiety': -0.11464382002604165, 'median_scaled_anxiety': 0.31112502809375264}
# DEBUG ROW: {'window_start_index': 252, 'window_start_TR': 252, 'mean_anxiety': -0.07415648669270831, 'mean_scaled_anxiety': 0.3259935395386211, 'median_anxiety': -0.00039398669270835013, 'median_scaled_anxiety': 0.35308197646833017}
# DEBUG ROW: {'window_start_index': 257, 'window_start_TR': 257, 'mean_anxiety': -0.06221531447048611, 'mean_scaled_anxiety': 0.33037879885885096, 'median_anxiety': -0.00039398669270835013, 'median_scaled_anxiety': 0.35308197646833017}
# DEBUG ROW: {'window_start_index': 262, 'window_start_TR': 262, 'mean_anxiety': -0.04201038669270835, 'mean_scaled_anxiety': 0.3377988281661231, 'median_anxiety': 0.02466384664062495, 'median_scaled_anxiety': 0.3622841799978358}
# DEBUG ROW: {'window_start_index': 267, 'window_start_TR': 267, 'mean_anxiety': -0.018956336692708346, 'mean_scaled_anxiety': 0.3462651651178176, 'median_anxiety': 0.10093284664062496, 'median_scaled_anxiety': 0.39029310046815574}
# DEBUG ROW: {'window_start_index': 272, 'window_start_TR': 272, 'mean_anxiety': 0.01472774664062498, 'mean_scaled_anxiety': 0.35863526058516293, 'median_anxiety': 0.10093284664062496, 'median_scaled_anxiety': 0.39029310046815574}
# DEBUG ROW: {'window_start_index': 277, 'window_start_TR': 277, 'mean_anxiety': 0.026454802196180533, 'mean_scaled_anxiety': 0.36294188800136845, 'median_anxiety': 0.10093284664062496, 'median_scaled_anxiety': 0.39029310046815574}
# DEBUG ROW: {'window_start_index': 282, 'window_start_TR': 282, 'mean_anxiety': 0.026448029973958304, 'mean_scaled_anxiety': 0.36293940097998845, 'median_anxiety': 0.10093284664062496, 'median_scaled_anxiety': 0.39029310046815574}
# DEBUG ROW: {'window_start_index': 287, 'window_start_TR': 287, 'mean_anxiety': 0.008324368862847197, 'mean_scaled_anxiety': 0.35628369312106617, 'median_anxiety': 0.10093284664062496, 'median_scaled_anxiety': 0.39029310046815574}
# DEBUG ROW: {'window_start_index': 292, 'window_start_TR': 292, 'mean_anxiety': -0.02719025891493058, 'mean_scaled_anxiety': 0.3432413510822195, 'median_anxiety': 0.10093284664062496, 'median_scaled_anxiety': 0.39029310046815574}
# DEBUG ROW: {'window_start_index': 297, 'window_start_TR': 297, 'mean_anxiety': -0.08479422002604167, 'mean_scaled_anxiety': 0.32208695328578163, 'median_anxiety': 0.06782717997395825, 'median_scaled_anxiety': 0.37813542192531935}
# DEBUG ROW: {'window_start_index': 302, 'window_start_TR': 302, 'mean_anxiety': -0.13915798669270835, 'mean_scaled_anxiety': 0.3021224799475485, 'median_anxiety': -0.303629653359375, 'median_scaled_anxiety': 0.24172213601636225}
# DEBUG ROW: {'window_start_index': 307, 'window_start_TR': 307, 'mean_anxiety': -0.1794369644704861, 'mean_scaled_anxiety': 0.2873304847043493, 'median_anxiety': -0.3173628200260416, 'median_scaled_anxiety': 0.2366787871725028}
# DEBUG ROW: {'window_start_index': 312, 'window_start_TR': 312, 'mean_anxiety': -0.19557969224826388, 'mean_scaled_anxiety': 0.2814022520213221, 'median_anxiety': -0.3173628200260416, 'median_scaled_anxiety': 0.2366787871725028}
# DEBUG ROW: {'window_start_index': 317, 'window_start_TR': 317, 'mean_anxiety': -0.1288762589149305, 'mean_scaled_anxiety': 0.3058983272200349, 'median_anxiety': -0.3173628200260416, 'median_scaled_anxiety': 0.2366787871725028}
# DEBUG ROW: {'window_start_index': 322, 'window_start_TR': 322, 'mean_anxiety': -0.01126429780381943, 'mean_scaled_anxiety': 0.3490899786789432, 'median_anxiety': -0.3173628200260416, 'median_scaled_anxiety': 0.2366787871725028}
# ✅ Saved: Chatter_sliding_windows_csv/sub-S32_anxiety_windows.csv with 51 windows
# 📊 Columns: ['window_start_index', 'window_start_TR', 'mean_anxiety', 'mean_scaled_anxiety', 'median_anxiety', 'median_scaled_anxiety', 'binned_by_mean', 'binned_by_median']
# 📊 Bin counts (mean):
# binned_by_mean
# medium    40
# low       11
# Name: count, dtype: int64
# 📊 Bin counts (median):
# binned_by_median
# medium    40
# low       11
# Name: count, dtype: int64

# %% [markdown]
# It seems like it is best to bin by mean anxiety value

# %% [markdown]
# # Calculating functional connectivity

# %% [markdown]
# ### ROI Time Series

# %% [markdown]
# We are going to start with doing this just for LessonLearned because it has better sample spreads with low vs medium vs high

# %%
# Extract ROI time series for every subject 

import os
import numpy as np
from nilearn.input_data import NiftiLabelsMasker
from nilearn import datasets

# === CONFIGURE ===
bold_dir = "LessonLearned_MNI_bold"    
output_dir = "roi_timeseries"
t_r = 1.2999999523162842
os.makedirs(output_dir, exist_ok=True)

# === LOAD SCHAEFER ATLAS ===
atlas = datasets.fetch_atlas_schaefer_2018(n_rois=100, yeo_networks=7)
atlas_img = atlas.maps

# === SETUP MASKER ===
masker = NiftiLabelsMasker(labels_img=atlas_img, standardize=True, t_r=t_r)

# === LOOP THROUGH BOLD FILES ===
for fname in os.listdir(bold_dir):
    if "space-MNI" in fname and fname.endswith((".nii", ".nii.gz")):
        subj = fname.split("_")[0]  # e.g., 'sub-S01'
        bold_path = os.path.join(bold_dir, fname)
        out_path = os.path.join(output_dir, f"{subj}.npy")

        try:
            print(f"🧠 Extracting ROI time series for {subj}")
            roi_ts = masker.fit_transform(bold_path)
            np.save(out_path, roi_ts)
            print(f"✅ Saved: {out_path} — shape: {roi_ts.shape}")
        except Exception as e:
            print(f"❌ Error for {subj}: {e}")
# Out:
# [get_dataset_dir] Dataset found in /Users/emmasombers/nilearn_data/schaefer_2018
# 🧠 Extracting ROI time series for sub-S01
# ✅ Saved: roi_timeseries/sub-S01.npy — shape: (665, 100)
# 🧠 Extracting ROI time series for sub-S19
# ✅ Saved: roi_timeseries/sub-S19.npy — shape: (668, 100)
# 🧠 Extracting ROI time series for sub-S23
# ✅ Saved: roi_timeseries/sub-S23.npy — shape: (668, 100)
# 🧠 Extracting ROI time series for sub-S20
# ✅ Saved: roi_timeseries/sub-S20.npy — shape: (668, 100)
# 🧠 Extracting ROI time series for sub-S22
# ✅ Saved: roi_timeseries/sub-S22.npy — shape: (668, 100)
# 🧠 Extracting ROI time series for sub-S27
# ✅ Saved: roi_timeseries/sub-S27.npy — shape: (670, 100)
# 🧠 Extracting ROI time series for sub-S02
# ✅ Saved: roi_timeseries/sub-S02.npy — shape: (668, 100)
# 🧠 Extracting ROI time series for sub-S05
# ✅ Saved: roi_timeseries/sub-S05.npy — shape: (670, 100)
# 🧠 Extracting ROI time series for sub-S17
# ✅ Saved: roi_timeseries/sub-S17.npy — shape: (668, 100)
# 🧠 Extracting ROI time series for sub-S32
# ✅ Saved: roi_timeseries/sub-S32.npy — shape: (668, 100)
# 🧠 Extracting ROI time series for sub-S03
# ✅ Saved: roi_timeseries/sub-S03.npy — shape: (669, 100)
# 🧠 Extracting ROI time series for sub-S21
# ✅ Saved: roi_timeseries/sub-S21.npy — shape: (668, 100)
# 🧠 Extracting ROI time series for sub-S08
# ✅ Saved: roi_timeseries/sub-S08.npy — shape: (672, 100)
# 🧠 Extracting ROI time series for sub-S14
# ✅ Saved: roi_timeseries/sub-S14.npy — shape: (669, 100)
# 🧠 Extracting ROI time series for sub-S13
# ✅ Saved: roi_timeseries/sub-S13.npy — shape: (668, 100)
# 🧠 Extracting ROI time series for sub-S31
# ✅ Saved: roi_timeseries/sub-S31.npy — shape: (668, 100)
# 🧠 Extracting ROI time series for sub-S24
# ✅ Saved: roi_timeseries/sub-S24.npy — shape: (672, 100)
# 🧠 Extracting ROI time series for sub-S09
# ✅ Saved: roi_timeseries/sub-S09.npy — shape: (668, 100)
# 🧠 Extracting ROI time series for sub-S04
# ✅ Saved: roi_timeseries/sub-S04.npy — shape: (668, 100)
# 🧠 Extracting ROI time series for sub-S30
# ✅ Saved: roi_timeseries/sub-S30.npy — shape: (692, 100)
# 🧠 Extracting ROI time series for sub-S06
# ✅ Saved: roi_timeseries/sub-S06.npy — shape: (668, 100)
# 🧠 Extracting ROI time series for sub-S25
# ✅ Saved: roi_timeseries/sub-S25.npy — shape: (668, 100)
# 🧠 Extracting ROI time series for sub-S10
# ✅ Saved: roi_timeseries/sub-S10.npy — shape: (668, 100)
# 🧠 Extracting ROI time series for sub-S15
# ✅ Saved: roi_timeseries/sub-S15.npy — shape: (671, 100)
# 🧠 Extracting ROI time series for sub-S29
# ✅ Saved: roi_timeseries/sub-S29.npy — shape: (669, 100)
# 🧠 Extracting ROI time series for sub-S07
# ✅ Saved: roi_timeseries/sub-S07.npy — shape: (669, 100)
# 🧠 Extracting ROI time series for sub-S11
# ✅ Saved: roi_timeseries/sub-S11.npy — shape: (668, 100)
# 🧠 Extracting ROI time series for sub-S16
# ✅ Saved: roi_timeseries/sub-S16.npy — shape: (668, 100)
# 🧠 Extracting ROI time series for sub-S26
# ✅ Saved: roi_timeseries/sub-S26.npy — shape: (668, 100)
# 🧠 Extracting ROI time series for sub-S28
# ✅ Saved: roi_timeseries/sub-S28.npy — shape: (669, 100)

# %% [markdown]
# ### Connectivity Calculation and Label Creation

# %%
import os
import numpy as np
import pandas as pd
from nilearn.connectome import ConnectivityMeasure

# === CONFIGURATION ===
roi_dir = "roi_timeseries"  # Folder with sub-XX.npy time series
windows_dir = "LessonLearned_sliding_windows_csv"  # Folder with sub-XX_anxiety_windows.csv
fc_output_dir = "fc_matrices"  # Where to save output
window_size = 60  # Number of timepoints per window
os.makedirs(fc_output_dir, exist_ok=True)

# === FC TOOL ===
connectivity = ConnectivityMeasure(kind="correlation")

# === LOOP THROUGH SUBJECTS ===
for fname in os.listdir(roi_dir):
    if not fname.endswith(".npy"):
        continue

    subj = fname.replace(".npy", "")  # e.g., 'sub-S01'
    roi_path = os.path.join(roi_dir, fname)
    window_csv = os.path.join(windows_dir, f"{subj}_anxiety_windows.csv")

    if not os.path.exists(window_csv):
        print(f"⚠️ No window file for {subj}, skipping.")
        continue

    print(f"\n🔄 Processing {subj}")

    # Load data
    roi_ts = np.load(roi_path)
    windows_df = pd.read_csv(window_csv)

    fc_matrices = []
    output_labels = []

    for _, row in windows_df.iterrows():
        start = int(row["window_start_index"])
        end = start + window_size

        if end > roi_ts.shape[0]:
            continue  # Skip if the window goes beyond the time series

        window_ts = roi_ts[start:end]
        if window_ts.shape[0] != window_size:
            continue  # Extra check to avoid malformed windows

        # Compute FC matrix
        fc = connectivity.fit_transform([window_ts])[0]  # shape: (100, 100)
        fc_matrices.append(fc)

        # Keep label info for this window
        output_labels.append({
            "window_start_TR": row["window_start_TR"],
            "mean_scaled_anxiety": row["mean_scaled_anxiety"],
            "binned_by_mean": row["binned_by_mean"]
        })

    if len(fc_matrices) == 0:
        print(f"⚠️ No valid windows for {subj}, skipping save.")
        continue

    # === SAVE OUTPUT ===
    np.save(os.path.join(fc_output_dir, f"{subj}_fc.npy"), np.array(fc_matrices))

    labels_df = pd.DataFrame(output_labels)
    labels_df.to_csv(os.path.join(fc_output_dir, f"{subj}_labels.csv"), index=False)

    print(f"✅ Saved: {subj}_fc.npy ({len(fc_matrices)} FCs) and {subj}_labels.csv")
# Out:
# 🔄 Processing sub-S32
# ✅ Saved: sub-S32_fc.npy (91 FCs) and sub-S32_labels.csv
#
# 🔄 Processing sub-S26
# ✅ Saved: sub-S26_fc.npy (91 FCs) and sub-S26_labels.csv
#
# 🔄 Processing sub-S27
# ✅ Saved: sub-S27_fc.npy (91 FCs) and sub-S27_labels.csv
#
# 🔄 Processing sub-S25
# ✅ Saved: sub-S25_fc.npy (91 FCs) and sub-S25_labels.csv
#
# 🔄 Processing sub-S31
# ✅ Saved: sub-S31_fc.npy (91 FCs) and sub-S31_labels.csv
#
# 🔄 Processing sub-S19
# ✅ Saved: sub-S19_fc.npy (91 FCs) and sub-S19_labels.csv
#
# 🔄 Processing sub-S30
# ✅ Saved: sub-S30_fc.npy (91 FCs) and sub-S30_labels.csv
#
# 🔄 Processing sub-S24
# ✅ Saved: sub-S24_fc.npy (91 FCs) and sub-S24_labels.csv
#
# 🔄 Processing sub-S08
# ✅ Saved: sub-S08_fc.npy (91 FCs) and sub-S08_labels.csv
#
# 🔄 Processing sub-S20
# ✅ Saved: sub-S20_fc.npy (91 FCs) and sub-S20_labels.csv
#
# 🔄 Processing sub-S21
# ✅ Saved: sub-S21_fc.npy (91 FCs) and sub-S21_labels.csv
#
# 🔄 Processing sub-S09
# ✅ Saved: sub-S09_fc.npy (91 FCs) and sub-S09_labels.csv
#
# 🔄 Processing sub-S23
# ✅ Saved: sub-S23_fc.npy (91 FCs) and sub-S23_labels.csv
#
# 🔄 Processing sub-S22
# ✅ Saved: sub-S22_fc.npy (91 FCs) and sub-S22_labels.csv
#
# 🔄 Processing sub-S13
# ✅ Saved: sub-S13_fc.npy (91 FCs) and sub-S13_labels.csv
#
# 🔄 Processing sub-S07
# ✅ Saved: sub-S07_fc.npy (91 FCs) and sub-S07_labels.csv
#
# 🔄 Processing sub-S06
# ✅ Saved: sub-S06_fc.npy (91 FCs) and sub-S06_labels.csv
#
# 🔄 Processing sub-S04
# ✅ Saved: sub-S04_fc.npy (91 FCs) and sub-S04_labels.csv
#
# 🔄 Processing sub-S10
# ✅ Saved: sub-S10_fc.npy (91 FCs) and sub-S10_labels.csv
#
# 🔄 Processing sub-S11
# ✅ Saved: sub-S11_fc.npy (91 FCs) and sub-S11_labels.csv
#
# 🔄 Processing sub-S05
# ✅ Saved: sub-S05_fc.npy (91 FCs) and sub-S05_labels.csv
#
# 🔄 Processing sub-S29
# ✅ Saved: sub-S29_fc.npy (91 FCs) and sub-S29_labels.csv
#
# 🔄 Processing sub-S01
# ✅ Saved: sub-S01_fc.npy (91 FCs) and sub-S01_labels.csv
#
# 🔄 Processing sub-S15
# ✅ Saved: sub-S15_fc.npy (91 FCs) and sub-S15_labels.csv
#
# 🔄 Processing sub-S14
# ✅ Saved: sub-S14_fc.npy (91 FCs) and sub-S14_labels.csv
#
# 🔄 Processing sub-S28
# ✅ Saved: sub-S28_fc.npy (91 FCs) and sub-S28_labels.csv
#
# 🔄 Processing sub-S16
# ✅ Saved: sub-S16_fc.npy (91 FCs) and sub-S16_labels.csv
#
# 🔄 Processing sub-S02
# ✅ Saved: sub-S02_fc.npy (91 FCs) and sub-S02_labels.csv
#
# 🔄 Processing sub-S03
# ✅ Saved: sub-S03_fc.npy (91 FCs) and sub-S03_labels.csv
#
# 🔄 Processing sub-S17
# ✅ Saved: sub-S17_fc.npy (91 FCs) and sub-S17_labels.csv

# %%
# add a column to the labels splitting it 0-0.5 and 0.5-1 

label_dir = fc_matrices 

for fname in os.listdir(label_dir):
    if fname.endswith("_labels.csv"):
        fpath = os.path.join(label_dir, fname)
        df = pd.read_csv(fpath)

        # new bin column for low/high binary classification 
        df["binned_0.5"] = df["mean_scaled_anxiety"].apply(lambda x: "low" if x < 0.5 else "high")

        # save file 
        df.to_csv(fpath, index=False)
        print(f"✅ Updated {fname}")
